# %% [markdown]
# <a href="https://colab.research.google.com/github/yurnero14/AML_2023_2024/blob/main/Correct_SemNovProj_23_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cu121

# %%
# installing pointnet++
# !pip install ninja
# !git clone https://github.com/erikwijmans/Pointnet2_PyTorch
# %cd /content/Pointnet2_PyTorch
# !python setup.py install

# moving to root directory
# %cd ..
# Out:
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (1.11.1.1)
# fatal: destination path 'Pointnet2_PyTorch' already exists and is not an empty directory.
# /content/Pointnet2_PyTorch
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing pointnet2.egg-info/PKG-INFO
# writing dependency_links to pointnet2.egg-info/dependency_links.txt
# writing requirements to pointnet2.egg-info/requires.txt
# writing top-level names to pointnet2.egg-info/top_level.txt
# reading manifest file 'pointnet2.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'pointnet2.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pointnet2
# copying build/lib/pointnet2/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2
# creating build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_ssg_sem.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_msg_sem.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_ssg_cls.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_msg_cls.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# creating build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/data_utils.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/Indoor3DSemSegLoader.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/ModelNet40Loader.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/train.py -> build/bdist.linux-x86_64/egg/pointnet2
# copying build/lib/pointnet2/_version.py -> build/bdist.linux-x86_64/egg/pointnet2
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_ssg_sem.py to pointnet2_ssg_sem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_msg_sem.py to pointnet2_msg_sem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_ssg_cls.py to pointnet2_ssg_cls.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_msg_cls.py to pointnet2_msg_cls.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/data_utils.py to data_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/Indoor3DSemSegLoader.py to Indoor3DSemSegLoader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/ModelNet40Loader.py to ModelNet40Loader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/train.py to train.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/_version.py to _version.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# pointnet2.data.__pycache__.Indoor3DSemSegLoader.cpython-310: module references __file__
# pointnet2.data.__pycache__.ModelNet40Loader.cpython-310: module references __file__
# creating 'dist/pointnet2-3.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pointnet2-3.0.0-py3.10.egg
# removing '/usr/local/lib/python3.10/dist-packages/pointnet2-3.0.0-py3.10.egg' (and everything under it)
# creating /usr/local/lib/python3.10/dist-packages/pointnet2-3.0.0-py3.10.egg
# Extracting pointnet2-3.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# pointnet2 3.0.0 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/pointnet2-3.0.0-py3.10.egg
# Processing dependencies for pointnet2==3.0.0
# Searching for pytorch-lightning==0.7.1
# Best match: pytorch-lightning 0.7.1
# Processing pytorch_lightning-0.7.1-py3.10.egg
# pytorch-lightning 0.7.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.10/dist-packages/pytorch_lightning-0.7.1-py3.10.egg
# Searching for hydra-core==0.11.3
# Best match: hydra-core 0.11.3
# Processing hydra_core-0.11.3-py3.10.egg
# hydra-core 0.11.3 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.10/dist-packages/hydra_core-0.11.3-py3.10.egg
# Searching for future==0.18.3
# Best match: future 0.18.3
# Adding future 0.18.3 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard==2.15.2
# Best match: tensorboard 2.15.2
# Adding tensorboard 2.15.2 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torch==2.1.0+cu121
# Best match: torch 2.1.0+cu121
# Adding torch 2.1.0+cu121 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.25.2
# Best match: numpy 1.25.2
# Adding numpy 1.25.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for omegaconf==1.4.1
# Best match: omegaconf 1.4.1
# Processing omegaconf-1.4.1-py3.10.egg
# omegaconf 1.4.1 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.10/dist-packages/omegaconf-1.4.1-py3.10.egg
# Searching for werkzeug==3.0.1
# Best match: werkzeug 3.0.1
# Adding werkzeug 3.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for protobuf==3.20.1
# Best match: protobuf 3.20.1
# Adding protobuf 3.20.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Markdown==3.5.2
# Best match: Markdown 3.5.2
# Adding Markdown 3.5.2 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth-oauthlib==1.2.0
# Best match: google-auth-oauthlib 1.2.0
# Adding google-auth-oauthlib 1.2.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth==2.27.0
# Best match: google-auth 2.27.0
# Adding google-auth 2.27.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for grpcio==1.60.1
# Best match: grpcio 1.60.1
# Adding grpcio 1.60.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for triton==2.1.0
# Best match: triton 2.1.0
# Adding triton 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fsspec==2023.6.0
# Best match: fsspec 2023.6.0
# Adding fsspec 2023.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Jinja2==3.1.3
# Best match: Jinja2 3.1.3
# Adding Jinja2 3.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for networkx==3.2.1
# Best match: networkx 3.2.1
# Adding networkx 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for typing-extensions==4.9.0
# Best match: typing-extensions 4.9.0
# Adding typing-extensions 4.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for filelock==3.13.1
# Best match: filelock 3.13.1
# Adding filelock 3.13.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.5
# Best match: MarkupSafe 2.1.5
# Adding MarkupSafe 2.1.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2024.2.2
# Best match: certifi 2024.2.2
# Adding certifi 2024.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1-modules==0.3.0
# Best match: pyasn1-modules 0.3.0
# Adding pyasn1-modules 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cachetools==5.3.2
# Best match: cachetools 5.3.2
# Adding cachetools 5.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1==0.5.1
# Best match: pyasn1 0.5.1
# Adding pyasn1 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for pointnet2==3.0.0
# /content

# %%
# install minimal requirements (pytorch is already installed in colab)
# !pip install timm==0.5.4 wandb tqdm h5py==3.6.0 protobuf==3.20.1 lmdb==1.2.1 msgpack-numpy==0.4.7.1 scikit-learn
# Out:
# Requirement already satisfied: timm==0.5.4 in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: h5py==3.6.0 in /usr/local/lib/python3.10/dist-packages (3.6.0)
# Requirement already satisfied: protobuf==3.20.1 in /usr/local/lib/python3.10/dist-packages (3.20.1)
# Requirement already satisfied: lmdb==1.2.1 in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: msgpack-numpy==0.4.7.1 in /usr/local/lib/python3.10/dist-packages (0.4.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (0.16.0+cu121)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py==3.6.0) (1.25.2)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from msgpack-numpy==0.4.7.1) (1.0.7)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.41)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.40.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.5.4) (9.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)

# %%
# made a new repo for you starting from 3DOS with modifications to help you running the code with colab.
# !git clone https://github.com/antoalli/SemNov_AML_DAAI_23-24
# Out:
# Cloning into 'SemNov_AML_DAAI_23-24'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 17), reused 14 (delta 14), pack-reused 132
# Receiving objects: 100% (160/160), 135.64 KiB | 1.00 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
# !ls
# Out:
# Pointnet2_PyTorch  sample_data	SemNov_AML_DAAI_23-24

# %%
# Move to the project directory after Git clone
# %cd /content/SemNov_AML_DAAI_23-24
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
# !ls /content/SemNov_AML_DAAI_23-24
# Out:
# base_args.py  classifiers  docs		     models		README.md	  supcon
# cfgs	      datasets	   download_data.sh  pointnet2_ops_lib	requirements.txt  utils

# %%
# check we're in project directory (should be SemNov_AML_DAAI_23)
# !pwd
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
# !sh download_data.sh
# Out:
# Downloading data in /content/SemNov_AML_DAAI_23-24/3D_OS_release_data
# ============Downloading ModelNet40 + OOD Splits in
# --2024-02-14 14:07:10--  https://www.dropbox.com/s/c2x3h59nxprjs21/modelnet40_normal_resampled.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar [following]
# --2024-02-14 14:07:11--  https://www.dropbox.com/s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com/cd/0/get/CNSvAcl-HCj5xsqvBbhivZhKzQHL06DkUurvGy6Ur6Wa6Td4bh5qbUsniivLPKNRhTXNucSUh8AT250tXCyk6HKE05_qcS3-g-QSId4bL00bsQJBqarmHYJPqHnrg-zc8k0FMuYkbAThme8eKkzHWjzW/file?dl=1# [following]
# --2024-02-14 14:07:11--  https://ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com/cd/0/get/CNSvAcl-HCj5xsqvBbhivZhKzQHL06DkUurvGy6Ur6Wa6Td4bh5qbUsniivLPKNRhTXNucSUh8AT250tXCyk6HKE05_qcS3-g-QSId4bL00bsQJBqarmHYJPqHnrg-zc8k0FMuYkbAThme8eKkzHWjzW/file?dl=1
# Resolving ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com (ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com)... 162.125.65.15, 2620:100:6017:15::a27d:20f
# Connecting to ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com (ucd49155b0dbb69eb65e6ee24e2e.dl-eu.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7599001600 (7.1G) [application/binary]
# Saving to: ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_modelnet40_normal_resampled.tar’
#
# /content/SemNov_AML 100%[===================>]   7.08G  20.0MB/s    in 6m 13s
#
# 2024-02-14 14:13:25 (19.4 MB/s) - ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_modelnet40_normal_resampled.tar’ saved [7599001600/7599001600]
#
# ============
# ============Downloading ScanObjectNN in
# --2024-02-14 14:14:18--  https://www.dropbox.com/s/gu0p3rych1k26b7/ScanObjectNN.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/gu0p3rych1k26b7/ScanObjectNN.tar [following]
# --2024-02-14 14:14:19--  https://www.dropbox.com/s/dl/gu0p3rych1k26b7/ScanObjectNN.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com/cd/0/get/CNStYf5w5X-7wX72WTp1yhpxBzT_tU1oZJBwjhOLneHOM1A199LJX67tYcLzArvOBMbzwxDDGzr2c5Q-_lMGsqOnmu2LtF_33MPQbaOj2gWU_r0fJhBTdPwPgv7YmVWaSuhyx56V3eRe1O5hchl36beH/file?dl=1# [following]
# --2024-02-14 14:14:19--  https://ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com/cd/0/get/CNStYf5w5X-7wX72WTp1yhpxBzT_tU1oZJBwjhOLneHOM1A199LJX67tYcLzArvOBMbzwxDDGzr2c5Q-_lMGsqOnmu2LtF_33MPQbaOj2gWU_r0fJhBTdPwPgv7YmVWaSuhyx56V3eRe1O5hchl36beH/file?dl=1
# Resolving ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com (ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com)... 162.125.2.15, 2620:100:6021:15::a27d:410f
# Connecting to ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com (ucabad9ea2f25323e7ae899d8ea5.dl-eu.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623662080 (2.4G) [application/binary]
# Saving to: ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_ScanObjectNN.tar’
#
# /content/SemNov_AML 100%[===================>]   2.44G  10.9MB/s    in 2m 23s
#
# 2024-02-14 14:16:43 (17.5 MB/s) - ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_ScanObjectNN.tar’ saved [2623662080/2623662080]
#
# ============
# Finished

# %%
# example: train a DGCNN classifier on SR1 (Synth->Real) - read docs + 3DOS paper!
# we use wandb for logging - you've to make a wandb account to check loss curves or you can choose "Don't visualize my results"
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --epochs 50 --exp_name DGCNN_CE_SR1_morpheus_sgd --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_Disc
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# training...
# ******************************
# 0/1 process initialized.
#
# 0/1 arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='train', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=50, batch_size=64, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path=None, src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none', log_dir='outputs/DGCNN_CE_SR1_morpheus_sgd', tb_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/tb-logs', models_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/models', backup_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/backup-code').
#
# ******************************
# Arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='train', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=50, batch_size=64, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path=None, src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none', log_dir='outputs/DGCNN_CE_SR1_morpheus_sgd', tb_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/tb-logs', models_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/models', backup_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/backup-code')
# Config: {'optimizer': {'type': 'sgd', 'skip_wd': [], 'weight_decay': 0.0001, 'kwargs': {'lr': 0.1, 'momentum': 0.9}}, 'scheduler': {'type': 'CosLR', 'kwargs': {'t_initial': 250, 'cycle_limit': 1, 'lr_min': 0.0001}}, 'model': {'ENCO_NAME': 'DGCNN', 'k': 20, 'emb_dims': 1024, 'dropout': 0.5, 'cla_input_dim': 2048, 'act': 'leakyrelu'}}
# World size: 1
#
# wandb: Currently logged in as: yurnero. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in /content/SemNov_AML_DAAI_23-24/wandb/run-20240214_152150-szt4g2y2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run DGCNN_CE_SR1_morpheus_sgd
# wandb: ⭐️ View project at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc
# wandb: 🚀 View run at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/runs/szt4g2y2
# Train transforms: [<utils.data_utils.PointcloudToTensor object at 0x7d86c5def940>, <utils.data_utils.RandomSample object at 0x7d86c5939240>, <utils.data_utils.AugmScale object at 0x7d86c5939510>, <utils.data_utils.AugmRotate object at 0x7d86c55c22c0>, <utils.data_utils.AugmRotatePerturbation object at 0x7d86c556fa90>, <utils.data_utils.AugmTranslate object at 0x7d86c5536110>, <utils.data_utils.AugmJitter object at 0x7d86c5535e10>]
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_train.h5
# ModelNet40_OOD - split: train, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# SR1 train_data len: 2378
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# SR1 train synset: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# Source: SR1
# Num training classes: 5
# dgcnn k: 20
# dgcnn emb_dims: 1024
# Clf - feature encoder: DGCNN
# Clf Head - num classes: 5, input dim: 2048, act: leakyrelu, dropout: 0.5
# Model:
# Classifier(
#   (enco): DGCNN(
#     (conv1): Sequential(
#       (0): Conv2d(6, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv4): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv5): Sequential(
#       (0): Conv1d(512, 1024, kernel_size=(1,), stride=(1,), bias=False)
#       (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (penultimate): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=False)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (head): Sequential(
#     (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
#
# param count:
# 1.8003 M
# Loss: CE
#
# it: [10/37-1/50], rank: [1/1], Loss: 0.8672, Loss avg: 1.1586, lr: 0.100000, BT: 0.79, DT: 0.00
# it: [20/37-1/50], rank: [1/1], Loss: 0.8365, Loss avg: 0.9709, lr: 0.100000, BT: 0.80, DT: 0.00
# it: [30/37-1/50], rank: [1/1], Loss: 0.7153, Loss avg: 0.8539, lr: 0.100000, BT: 0.80, DT: 0.00
# Train [1/50]	rank: [1/1], Loss: 0.8226, Acc: 0.7268, Bal Acc: 0.5318, BT: 1.13, DT: 0.02,  epoch time: 41.78
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:00<00:00,  5.00it/s]
# Test [1/50]	Acc: 0.8031, Bal Acc: 0.5702
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-2/50], rank: [1/1], Loss: 0.4879, Loss avg: 0.5952, lr: 0.099996, BT: 0.81, DT: 0.00
# it: [20/37-2/50], rank: [1/1], Loss: 0.6920, Loss avg: 0.5467, lr: 0.099996, BT: 0.83, DT: 0.01
# it: [30/37-2/50], rank: [1/1], Loss: 0.3254, Loss avg: 0.5288, lr: 0.099996, BT: 0.83, DT: 0.00
# Train [2/50]	rank: [1/1], Loss: 0.5112, Acc: 0.8459, Bal Acc: 0.7074, BT: 0.84, DT: 0.02,  epoch time: 31.07
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:00<00:00,  5.05it/s]
# Test [2/50]	Acc: 0.8469, Bal Acc: 0.6527
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-3/50], rank: [1/1], Loss: 0.3700, Loss avg: 0.2499, lr: 0.099984, BT: 0.85, DT: 0.01
# it: [20/37-3/50], rank: [1/1], Loss: 0.1452, Loss avg: 0.2585, lr: 0.099984, BT: 0.85, DT: 0.00
# it: [30/37-3/50], rank: [1/1], Loss: 0.2158, Loss avg: 0.2867, lr: 0.099984, BT: 0.86, DT: 0.00
# Train [3/50]	rank: [1/1], Loss: 0.2770, Acc: 0.9062, Bal Acc: 0.8049, BT: 0.87, DT: 0.02,  epoch time: 32.18
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.30it/s]
# Test [3/50]	Acc: 0.9531, Bal Acc: 0.9089
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-4/50], rank: [1/1], Loss: 0.2930, Loss avg: 0.2127, lr: 0.099965, BT: 0.87, DT: 0.00
# it: [20/37-4/50], rank: [1/1], Loss: 0.1429, Loss avg: 0.2110, lr: 0.099965, BT: 0.88, DT: 0.00
# it: [30/37-4/50], rank: [1/1], Loss: 0.2148, Loss avg: 0.2293, lr: 0.099965, BT: 0.87, DT: 0.00
# Train [4/50]	rank: [1/1], Loss: 0.2271, Acc: 0.9316, Bal Acc: 0.8695, BT: 0.89, DT: 0.02,  epoch time: 33.00
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.35it/s]
# Test [4/50]	Acc: 0.9437, Bal Acc: 0.9423
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-5/50], rank: [1/1], Loss: 0.2074, Loss avg: 0.1978, lr: 0.099937, BT: 0.86, DT: 0.00
# it: [20/37-5/50], rank: [1/1], Loss: 0.3687, Loss avg: 0.1846, lr: 0.099937, BT: 0.86, DT: 0.00
# it: [30/37-5/50], rank: [1/1], Loss: 0.1798, Loss avg: 0.1790, lr: 0.099937, BT: 0.86, DT: 0.00
# Train [5/50]	rank: [1/1], Loss: 0.1921, Acc: 0.9379, Bal Acc: 0.8715, BT: 0.87, DT: 0.01,  epoch time: 32.43
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.58it/s]
# Test [5/50]	Acc: 0.7844, Bal Acc: 0.8075
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-6/50], rank: [1/1], Loss: 0.1372, Loss avg: 0.2001, lr: 0.099901, BT: 0.87, DT: 0.00
# it: [20/37-6/50], rank: [1/1], Loss: 0.3011, Loss avg: 0.1730, lr: 0.099901, BT: 0.87, DT: 0.00
# it: [30/37-6/50], rank: [1/1], Loss: 0.1765, Loss avg: 0.1616, lr: 0.099901, BT: 0.87, DT: 0.00
# Train [6/50]	rank: [1/1], Loss: 0.1540, Acc: 0.9506, Bal Acc: 0.8985, BT: 0.89, DT: 0.03,  epoch time: 33.07
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.90it/s]
# Test [6/50]	Acc: 0.9500, Bal Acc: 0.9572
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-7/50], rank: [1/1], Loss: 0.3592, Loss avg: 0.2080, lr: 0.099858, BT: 0.87, DT: 0.00
# it: [20/37-7/50], rank: [1/1], Loss: 0.2488, Loss avg: 0.1802, lr: 0.099858, BT: 0.87, DT: 0.00
# it: [30/37-7/50], rank: [1/1], Loss: 0.1631, Loss avg: 0.1629, lr: 0.099858, BT: 0.87, DT: 0.00
# Train [7/50]	rank: [1/1], Loss: 0.1637, Acc: 0.9493, Bal Acc: 0.8892, BT: 0.88, DT: 0.01,  epoch time: 32.65
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.72it/s]
# Test [7/50]	Acc: 0.9594, Bal Acc: 0.9365
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-8/50], rank: [1/1], Loss: 0.1951, Loss avg: 0.1110, lr: 0.099807, BT: 0.86, DT: 0.00
# it: [20/37-8/50], rank: [1/1], Loss: 0.2258, Loss avg: 0.1355, lr: 0.099807, BT: 0.87, DT: 0.00
# it: [30/37-8/50], rank: [1/1], Loss: 0.0661, Loss avg: 0.1407, lr: 0.099807, BT: 0.87, DT: 0.00
# Train [8/50]	rank: [1/1], Loss: 0.1516, Acc: 0.9552, Bal Acc: 0.9182, BT: 0.88, DT: 0.01,  epoch time: 32.47
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.81it/s]
# Test [8/50]	Acc: 0.7656, Bal Acc: 0.8022
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-9/50], rank: [1/1], Loss: 0.0441, Loss avg: 0.0915, lr: 0.099748, BT: 0.87, DT: 0.00
# it: [20/37-9/50], rank: [1/1], Loss: 0.1093, Loss avg: 0.1171, lr: 0.099748, BT: 0.87, DT: 0.00
# it: [30/37-9/50], rank: [1/1], Loss: 0.0646, Loss avg: 0.1220, lr: 0.099748, BT: 0.87, DT: 0.00
# Train [9/50]	rank: [1/1], Loss: 0.1241, Acc: 0.9603, Bal Acc: 0.9235, BT: 0.88, DT: 0.02,  epoch time: 32.74
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.82it/s]
# Test [9/50]	Acc: 0.9500, Bal Acc: 0.9240
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-10/50], rank: [1/1], Loss: 0.0912, Loss avg: 0.0859, lr: 0.099681, BT: 0.87, DT: 0.01
# it: [20/37-10/50], rank: [1/1], Loss: 0.1603, Loss avg: 0.0983, lr: 0.099681, BT: 0.87, DT: 0.00
# it: [30/37-10/50], rank: [1/1], Loss: 0.0995, Loss avg: 0.0968, lr: 0.099681, BT: 0.87, DT: 0.00
# Train [10/50]	rank: [1/1], Loss: 0.1002, Acc: 0.9671, Bal Acc: 0.9343, BT: 0.88, DT: 0.02,  epoch time: 32.83
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.35it/s]
# Test [10/50]	Acc: 0.9469, Bal Acc: 0.9370
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-11/50], rank: [1/1], Loss: 0.0429, Loss avg: 0.1202, lr: 0.099606, BT: 0.87, DT: 0.01
# it: [20/37-11/50], rank: [1/1], Loss: 0.0323, Loss avg: 0.0932, lr: 0.099606, BT: 0.87, DT: 0.00
# it: [30/37-11/50], rank: [1/1], Loss: 0.1921, Loss avg: 0.0910, lr: 0.099606, BT: 0.87, DT: 0.00
# Train [11/50]	rank: [1/1], Loss: 0.0941, Acc: 0.9730, Bal Acc: 0.9446, BT: 0.88, DT: 0.02,  epoch time: 32.75
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.55it/s]
# Test [11/50]	Acc: 0.9688, Bal Acc: 0.9519
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-12/50], rank: [1/1], Loss: 0.1379, Loss avg: 0.1163, lr: 0.099524, BT: 0.87, DT: 0.00
# it: [20/37-12/50], rank: [1/1], Loss: 0.1109, Loss avg: 0.1013, lr: 0.099524, BT: 0.87, DT: 0.00
# it: [30/37-12/50], rank: [1/1], Loss: 0.1264, Loss avg: 0.0902, lr: 0.099524, BT: 0.87, DT: 0.00
# Train [12/50]	rank: [1/1], Loss: 0.0866, Acc: 0.9704, Bal Acc: 0.9367, BT: 0.89, DT: 0.02,  epoch time: 32.82
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.75it/s]
# Test [12/50]	Acc: 0.9563, Bal Acc: 0.9465
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-13/50], rank: [1/1], Loss: 0.1335, Loss avg: 0.0792, lr: 0.099433, BT: 0.87, DT: 0.00
# it: [20/37-13/50], rank: [1/1], Loss: 0.0447, Loss avg: 0.0986, lr: 0.099433, BT: 0.87, DT: 0.00
# it: [30/37-13/50], rank: [1/1], Loss: 0.0154, Loss avg: 0.0948, lr: 0.099433, BT: 0.87, DT: 0.00
# Train [13/50]	rank: [1/1], Loss: 0.0941, Acc: 0.9730, Bal Acc: 0.9461, BT: 0.89, DT: 0.03,  epoch time: 33.19
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.77it/s]
# Test [13/50]	Acc: 0.9531, Bal Acc: 0.9242
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-14/50], rank: [1/1], Loss: 0.0289, Loss avg: 0.0512, lr: 0.099335, BT: 0.87, DT: 0.00
# it: [20/37-14/50], rank: [1/1], Loss: 0.1013, Loss avg: 0.0686, lr: 0.099335, BT: 0.87, DT: 0.00
# it: [30/37-14/50], rank: [1/1], Loss: 0.0923, Loss avg: 0.0734, lr: 0.099335, BT: 0.87, DT: 0.00
# Train [14/50]	rank: [1/1], Loss: 0.0793, Acc: 0.9734, Bal Acc: 0.9431, BT: 0.89, DT: 0.02,  epoch time: 32.82
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.73it/s]
# Test [14/50]	Acc: 0.8688, Bal Acc: 0.8692
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-15/50], rank: [1/1], Loss: 0.0414, Loss avg: 0.0851, lr: 0.099229, BT: 0.88, DT: 0.00
# it: [20/37-15/50], rank: [1/1], Loss: 0.0618, Loss avg: 0.0948, lr: 0.099229, BT: 0.87, DT: 0.01
# it: [30/37-15/50], rank: [1/1], Loss: 0.0121, Loss avg: 0.0762, lr: 0.099229, BT: 0.87, DT: 0.00
# Train [15/50]	rank: [1/1], Loss: 0.0889, Acc: 0.9730, Bal Acc: 0.9434, BT: 0.88, DT: 0.01,  epoch time: 32.67
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.86it/s]
# Test [15/50]	Acc: 0.9594, Bal Acc: 0.9052
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-16/50], rank: [1/1], Loss: 0.1979, Loss avg: 0.0999, lr: 0.099115, BT: 0.87, DT: 0.00
# it: [20/37-16/50], rank: [1/1], Loss: 0.0794, Loss avg: 0.0840, lr: 0.099115, BT: 0.87, DT: 0.00
# it: [30/37-16/50], rank: [1/1], Loss: 0.0145, Loss avg: 0.0805, lr: 0.099115, BT: 0.87, DT: 0.00
# Train [16/50]	rank: [1/1], Loss: 0.0796, Acc: 0.9742, Bal Acc: 0.9464, BT: 0.88, DT: 0.02,  epoch time: 32.76
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.91it/s]
# Test [16/50]	Acc: 0.9656, Bal Acc: 0.9587
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-17/50], rank: [1/1], Loss: 0.0286, Loss avg: 0.0506, lr: 0.098994, BT: 0.87, DT: 0.01
# it: [20/37-17/50], rank: [1/1], Loss: 0.0064, Loss avg: 0.0510, lr: 0.098994, BT: 0.87, DT: 0.00
# it: [30/37-17/50], rank: [1/1], Loss: 0.0234, Loss avg: 0.0452, lr: 0.098994, BT: 0.87, DT: 0.00
# Train [17/50]	rank: [1/1], Loss: 0.0545, Acc: 0.9802, Bal Acc: 0.9566, BT: 0.88, DT: 0.01,  epoch time: 32.61
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.33it/s]
# Test [17/50]	Acc: 0.9656, Bal Acc: 0.9515
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-18/50], rank: [1/1], Loss: 0.0750, Loss avg: 0.0355, lr: 0.098865, BT: 0.87, DT: 0.00
# it: [20/37-18/50], rank: [1/1], Loss: 0.1195, Loss avg: 0.0533, lr: 0.098865, BT: 0.86, DT: 0.00
# it: [30/37-18/50], rank: [1/1], Loss: 0.0461, Loss avg: 0.0611, lr: 0.098865, BT: 0.87, DT: 0.00
# Train [18/50]	rank: [1/1], Loss: 0.0670, Acc: 0.9818, Bal Acc: 0.9575, BT: 0.88, DT: 0.02,  epoch time: 32.73
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.63it/s]
# Test [18/50]	Acc: 0.9781, Bal Acc: 0.9600
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-19/50], rank: [1/1], Loss: 0.0268, Loss avg: 0.0344, lr: 0.098728, BT: 0.87, DT: 0.00
# it: [20/37-19/50], rank: [1/1], Loss: 0.2939, Loss avg: 0.0925, lr: 0.098728, BT: 0.87, DT: 0.00
# it: [30/37-19/50], rank: [1/1], Loss: 0.0339, Loss avg: 0.0997, lr: 0.098728, BT: 0.87, DT: 0.00
# Train [19/50]	rank: [1/1], Loss: 0.0934, Acc: 0.9755, Bal Acc: 0.9497, BT: 0.89, DT: 0.02,  epoch time: 32.83
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.84it/s]
# Test [19/50]	Acc: 0.9594, Bal Acc: 0.9387
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-20/50], rank: [1/1], Loss: 0.1333, Loss avg: 0.0815, lr: 0.098583, BT: 0.87, DT: 0.00
# it: [20/37-20/50], rank: [1/1], Loss: 0.0313, Loss avg: 0.0682, lr: 0.098583, BT: 0.87, DT: 0.00
# it: [30/37-20/50], rank: [1/1], Loss: 0.0305, Loss avg: 0.0752, lr: 0.098583, BT: 0.87, DT: 0.00
# Train [20/50]	rank: [1/1], Loss: 0.0765, Acc: 0.9755, Bal Acc: 0.9480, BT: 0.89, DT: 0.02,  epoch time: 32.97
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.65it/s]
# Test [20/50]	Acc: 0.9750, Bal Acc: 0.9639
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-21/50], rank: [1/1], Loss: 0.1077, Loss avg: 0.0754, lr: 0.098431, BT: 0.87, DT: 0.00
# it: [20/37-21/50], rank: [1/1], Loss: 0.0570, Loss avg: 0.0657, lr: 0.098431, BT: 0.87, DT: 0.00
# it: [30/37-21/50], rank: [1/1], Loss: 0.0661, Loss avg: 0.0750, lr: 0.098431, BT: 0.87, DT: 0.00
# Train [21/50]	rank: [1/1], Loss: 0.0708, Acc: 0.9768, Bal Acc: 0.9563, BT: 0.88, DT: 0.02,  epoch time: 32.74
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.76it/s]
# Test [21/50]	Acc: 0.9531, Bal Acc: 0.9092
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-22/50], rank: [1/1], Loss: 0.0264, Loss avg: 0.0385, lr: 0.098271, BT: 0.87, DT: 0.00
# it: [20/37-22/50], rank: [1/1], Loss: 0.0113, Loss avg: 0.0409, lr: 0.098271, BT: 0.87, DT: 0.01
# it: [30/37-22/50], rank: [1/1], Loss: 0.0665, Loss avg: 0.0492, lr: 0.098271, BT: 0.87, DT: 0.00
# Train [22/50]	rank: [1/1], Loss: 0.0517, Acc: 0.9810, Bal Acc: 0.9608, BT: 0.88, DT: 0.01,  epoch time: 32.69
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.77it/s]
# Test [22/50]	Acc: 0.9594, Bal Acc: 0.9457
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-23/50], rank: [1/1], Loss: 0.0509, Loss avg: 0.0652, lr: 0.098103, BT: 0.87, DT: 0.00
# it: [20/37-23/50], rank: [1/1], Loss: 0.0317, Loss avg: 0.0560, lr: 0.098103, BT: 0.87, DT: 0.00
# it: [30/37-23/50], rank: [1/1], Loss: 0.1223, Loss avg: 0.0525, lr: 0.098103, BT: 0.87, DT: 0.00
# Train [23/50]	rank: [1/1], Loss: 0.0523, Acc: 0.9818, Bal Acc: 0.9644, BT: 0.89, DT: 0.02,  epoch time: 32.83
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.88it/s]
# Test [23/50]	Acc: 0.9594, Bal Acc: 0.9388
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-24/50], rank: [1/1], Loss: 0.1748, Loss avg: 0.0828, lr: 0.097928, BT: 0.87, DT: 0.00
# it: [20/37-24/50], rank: [1/1], Loss: 0.0387, Loss avg: 0.0701, lr: 0.097928, BT: 0.87, DT: 0.00
# it: [30/37-24/50], rank: [1/1], Loss: 0.0335, Loss avg: 0.0620, lr: 0.097928, BT: 0.87, DT: 0.00
# Train [24/50]	rank: [1/1], Loss: 0.0581, Acc: 0.9814, Bal Acc: 0.9616, BT: 0.88, DT: 0.02,  epoch time: 32.77
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.45it/s]
# Test [24/50]	Acc: 0.9594, Bal Acc: 0.9250
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-25/50], rank: [1/1], Loss: 0.0394, Loss avg: 0.0517, lr: 0.097745, BT: 0.87, DT: 0.00
# it: [20/37-25/50], rank: [1/1], Loss: 0.0352, Loss avg: 0.0532, lr: 0.097745, BT: 0.87, DT: 0.00
# it: [30/37-25/50], rank: [1/1], Loss: 0.0702, Loss avg: 0.0545, lr: 0.097745, BT: 0.87, DT: 0.00
# Train [25/50]	rank: [1/1], Loss: 0.0483, Acc: 0.9835, Bal Acc: 0.9689, BT: 0.88, DT: 0.02,  epoch time: 32.81
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.67it/s]
# Test [25/50]	Acc: 0.9625, Bal Acc: 0.9655
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-26/50], rank: [1/1], Loss: 0.0130, Loss avg: 0.0347, lr: 0.097555, BT: 0.87, DT: 0.00
# it: [20/37-26/50], rank: [1/1], Loss: 0.0513, Loss avg: 0.0455, lr: 0.097555, BT: 0.87, DT: 0.00
# it: [30/37-26/50], rank: [1/1], Loss: 0.0153, Loss avg: 0.0440, lr: 0.097555, BT: 0.87, DT: 0.00
# Train [26/50]	rank: [1/1], Loss: 0.0509, Acc: 0.9814, Bal Acc: 0.9594, BT: 0.89, DT: 0.02,  epoch time: 32.82
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.64it/s]
# Test [26/50]	Acc: 0.9656, Bal Acc: 0.9677
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-27/50], rank: [1/1], Loss: 0.0522, Loss avg: 0.0556, lr: 0.097358, BT: 0.87, DT: 0.00
# it: [20/37-27/50], rank: [1/1], Loss: 0.0197, Loss avg: 0.0476, lr: 0.097358, BT: 0.87, DT: 0.00
# it: [30/37-27/50], rank: [1/1], Loss: 0.0463, Loss avg: 0.0486, lr: 0.097358, BT: 0.87, DT: 0.00
# Train [27/50]	rank: [1/1], Loss: 0.0526, Acc: 0.9852, Bal Acc: 0.9684, BT: 0.89, DT: 0.02,  epoch time: 33.07
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.68it/s]
# Test [27/50]	Acc: 0.9750, Bal Acc: 0.9671
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-28/50], rank: [1/1], Loss: 0.0551, Loss avg: 0.0514, lr: 0.097152, BT: 0.87, DT: 0.00
# it: [20/37-28/50], rank: [1/1], Loss: 0.0157, Loss avg: 0.0458, lr: 0.097152, BT: 0.87, DT: 0.00
# it: [30/37-28/50], rank: [1/1], Loss: 0.0762, Loss avg: 0.0464, lr: 0.097152, BT: 0.87, DT: 0.00
# Train [28/50]	rank: [1/1], Loss: 0.0419, Acc: 0.9831, Bal Acc: 0.9666, BT: 0.89, DT: 0.01,  epoch time: 33.18
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.58it/s]
# Test [28/50]	Acc: 0.9625, Bal Acc: 0.9576
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-29/50], rank: [1/1], Loss: 0.0114, Loss avg: 0.0564, lr: 0.096940, BT: 0.87, DT: 0.00
# it: [20/37-29/50], rank: [1/1], Loss: 0.0330, Loss avg: 0.0585, lr: 0.096940, BT: 0.87, DT: 0.00
# it: [30/37-29/50], rank: [1/1], Loss: 0.0599, Loss avg: 0.0585, lr: 0.096940, BT: 0.87, DT: 0.00
# Train [29/50]	rank: [1/1], Loss: 0.0560, Acc: 0.9818, Bal Acc: 0.9617, BT: 0.88, DT: 0.02,  epoch time: 32.76
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
#   warnings.warn(_create_warning_msg(
# it: [10/37-41/50], rank: [1/1], Loss: 0.0091, Loss avg: 0.0200, lr: 0.093822, BT: 0.87, DT: 0.00
# it: [20/37-41/50], rank: [1/1], Loss: 0.0973, Loss avg: 0.0314, lr: 0.093822, BT: 0.87, DT: 0.00
# it: [30/37-41/50], rank: [1/1], Loss: 0.0496, Loss avg: 0.0344, lr: 0.093822, BT: 0.87, DT: 0.00
# Train [41/50]	rank: [1/1], Loss: 0.0340, Acc: 0.9882, Bal Acc: 0.9780, BT: 0.89, DT: 0.03,  epoch time: 33.09
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.65it/s]
# Test [41/50]	Acc: 0.9719, Bal Acc: 0.9557
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-42/50], rank: [1/1], Loss: 0.0037, Loss avg: 0.0246, lr: 0.093516, BT: 0.87, DT: 0.00
# it: [20/37-42/50], rank: [1/1], Loss: 0.0375, Loss avg: 0.0204, lr: 0.093516, BT: 0.87, DT: 0.00
# it: [30/37-42/50], rank: [1/1], Loss: 0.0519, Loss avg: 0.0277, lr: 0.093516, BT: 0.87, DT: 0.00
# Train [42/50]	rank: [1/1], Loss: 0.0292, Acc: 0.9890, Bal Acc: 0.9718, BT: 0.88, DT: 0.01,  epoch time: 32.70
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.52it/s]
# Test [42/50]	Acc: 0.9437, Bal Acc: 0.9365
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-43/50], rank: [1/1], Loss: 0.0954, Loss avg: 0.0345, lr: 0.093203, BT: 0.87, DT: 0.00
# it: [20/37-43/50], rank: [1/1], Loss: 0.0497, Loss avg: 0.0326, lr: 0.093203, BT: 0.87, DT: 0.01
# it: [30/37-43/50], rank: [1/1], Loss: 0.0185, Loss avg: 0.0293, lr: 0.093203, BT: 0.87, DT: 0.00
# Train [43/50]	rank: [1/1], Loss: 0.0327, Acc: 0.9890, Bal Acc: 0.9757, BT: 0.89, DT: 0.02,  epoch time: 32.98
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.93it/s]
# Test [43/50]	Acc: 0.9563, Bal Acc: 0.9464
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-44/50], rank: [1/1], Loss: 0.0623, Loss avg: 0.0425, lr: 0.092883, BT: 0.87, DT: 0.00
# it: [20/37-44/50], rank: [1/1], Loss: 0.0046, Loss avg: 0.0435, lr: 0.092883, BT: 0.87, DT: 0.00
# it: [30/37-44/50], rank: [1/1], Loss: 0.0047, Loss avg: 0.0366, lr: 0.092883, BT: 0.87, DT: 0.00
# Train [44/50]	rank: [1/1], Loss: 0.0357, Acc: 0.9882, Bal Acc: 0.9718, BT: 0.88, DT: 0.02,  epoch time: 32.76
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.81it/s]
# Test [44/50]	Acc: 0.9719, Bal Acc: 0.9574
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-45/50], rank: [1/1], Loss: 0.0179, Loss avg: 0.0465, lr: 0.092557, BT: 0.87, DT: 0.00
# it: [20/37-45/50], rank: [1/1], Loss: 0.0190, Loss avg: 0.0338, lr: 0.092557, BT: 0.87, DT: 0.00
# it: [30/37-45/50], rank: [1/1], Loss: 0.0429, Loss avg: 0.0337, lr: 0.092557, BT: 0.87, DT: 0.00
# Train [45/50]	rank: [1/1], Loss: 0.0336, Acc: 0.9873, Bal Acc: 0.9761, BT: 0.88, DT: 0.02,  epoch time: 32.83
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.58it/s]
# Test [45/50]	Acc: 0.9719, Bal Acc: 0.9632
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-46/50], rank: [1/1], Loss: 0.0296, Loss avg: 0.0361, lr: 0.092224, BT: 0.87, DT: 0.01
# it: [20/37-46/50], rank: [1/1], Loss: 0.0117, Loss avg: 0.0409, lr: 0.092224, BT: 0.87, DT: 0.00
# it: [30/37-46/50], rank: [1/1], Loss: 0.1289, Loss avg: 0.0386, lr: 0.092224, BT: 0.87, DT: 0.00
# Train [46/50]	rank: [1/1], Loss: 0.0370, Acc: 0.9890, Bal Acc: 0.9828, BT: 0.88, DT: 0.01,  epoch time: 32.62
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.05it/s]
# Test [46/50]	Acc: 0.9563, Bal Acc: 0.9074
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-47/50], rank: [1/1], Loss: 0.0116, Loss avg: 0.0157, lr: 0.091885, BT: 0.87, DT: 0.00
# it: [20/37-47/50], rank: [1/1], Loss: 0.0190, Loss avg: 0.0210, lr: 0.091885, BT: 0.87, DT: 0.00
# it: [30/37-47/50], rank: [1/1], Loss: 0.0085, Loss avg: 0.0202, lr: 0.091885, BT: 0.87, DT: 0.00
# Train [47/50]	rank: [1/1], Loss: 0.0212, Acc: 0.9920, Bal Acc: 0.9865, BT: 0.88, DT: 0.02,  epoch time: 32.76
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.78it/s]
# Test [47/50]	Acc: 0.9750, Bal Acc: 0.9594
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-48/50], rank: [1/1], Loss: 0.1020, Loss avg: 0.0301, lr: 0.091538, BT: 0.87, DT: 0.00
# it: [20/37-48/50], rank: [1/1], Loss: 0.0136, Loss avg: 0.0317, lr: 0.091538, BT: 0.87, DT: 0.00
# it: [30/37-48/50], rank: [1/1], Loss: 0.0281, Loss avg: 0.0355, lr: 0.091538, BT: 0.87, DT: 0.00
# Train [48/50]	rank: [1/1], Loss: 0.0339, Acc: 0.9869, Bal Acc: 0.9761, BT: 0.89, DT: 0.03,  epoch time: 33.16
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.56it/s]
# Test [48/50]	Acc: 0.9656, Bal Acc: 0.9610
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-49/50], rank: [1/1], Loss: 0.0025, Loss avg: 0.0529, lr: 0.091185, BT: 0.87, DT: 0.00
# it: [20/37-49/50], rank: [1/1], Loss: 0.0160, Loss avg: 0.0392, lr: 0.091185, BT: 0.87, DT: 0.00
# it: [30/37-49/50], rank: [1/1], Loss: 0.0181, Loss avg: 0.0320, lr: 0.091185, BT: 0.87, DT: 0.00
# Train [49/50]	rank: [1/1], Loss: 0.0371, Acc: 0.9890, Bal Acc: 0.9843, BT: 0.88, DT: 0.02,  epoch time: 32.75
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.83it/s]
# Test [49/50]	Acc: 0.9625, Bal Acc: 0.9194
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-50/50], rank: [1/1], Loss: 0.0566, Loss avg: 0.0713, lr: 0.090826, BT: 0.87, DT: 0.00
# it: [20/37-50/50], rank: [1/1], Loss: 0.0016, Loss avg: 0.0652, lr: 0.090826, BT: 0.87, DT: 0.02
# it: [30/37-50/50], rank: [1/1], Loss: 0.0686, Loss avg: 0.0611, lr: 0.090826, BT: 0.87, DT: 0.00
# Train [50/50]	rank: [1/1], Loss: 0.0548, Acc: 0.9835, Bal Acc: 0.9661, BT: 0.88, DT: 0.01,  epoch time: 32.70
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.75it/s]
# Test [50/50]	Acc: 0.9750, Bal Acc: 0.9828
# Training finished - best test acc: 0.9844 at ep.: 40, time: 1760.6587579250336
# wandb:
# wandb: Run history:
# wandb:      test/ep_acc ▂▄▇▇▇▇▁▇█▇▇▄███▇▇▇▇▇██▇▇▇██▇█████▇▇█▇███
# wandb:  test/ep_bal_acc ▁▂▇▇█▇▅▇▇▇▇▆█▇█▇▇▇▇▇███▇▆██▇██▇▇█▇▇█▇███
# wandb:       test/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:     train/ep_acc ▁▄▆▆▇▇▇▇▇▇▇█████████████████████████████
# wandb: train/ep_bal_acc ▁▄▅▆▇▇▇▇▇▇▇▇▇██▇████████████████████████
# wandb:    train/ep_loss █▅▃▃▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    train/ep_time █▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:      train/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:         train/it ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:    train/it_loss █▅▂▃▂▃▂▂▁▂▁▂▃▁▁▂▁▂▂▁▁▁▂▁▁▁▂▁▁▁▁▁▂▁▁▁▂▂▁▂
# wandb:      train/it_lr ███████████▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▂▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:      test/ep_acc 0.975
# wandb:  test/ep_bal_acc 0.98282
# wandb:       test/epoch 50
# wandb:     train/ep_acc 0.98353
# wandb: train/ep_bal_acc 0.96611
# wandb:    train/ep_loss 0.05485
# wandb:    train/ep_time 32.70167
# wandb:      train/epoch 50
# wandb:         train/it 1843
# wandb:    train/it_loss 0.06863
# wandb:      train/it_lr 0.09083
# wandb:
# wandb: 🚀 View run DGCNN_CE_SR1_morpheus_sgd at: https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/runs/szt4g2y2
# wandb: ️⚡ View job at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzOTQwOTc5Mw==/version_details/v2
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240214_152150-szt4g2y2/logs

# %%
# !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl
# Out:
# Collecting KNN-CUDA==0.2
#   Downloading https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (1.2.2)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (2.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->KNN-CUDA==0.2) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1.0->KNN-CUDA==0.2) (1.3.0)
# Installing collected packages: KNN-CUDA
# Successfully installed KNN-CUDA-0.2

# %%
# !python classifiers/trainer_cla_md.py --script_mode eval  --config cfgs/dgcnn-cla.yaml --epochs 50 --exp_name DGCNN_CE_SR1_morpheus_sgd --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_Disc --ckpt_path /content/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1_morpheus_sgd/models/model_best.pth
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# out-of-distribution eval - Modelnet -> SONN ..
# Arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='eval', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=50, batch_size=1, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path='/content/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1_morpheus_sgd/models/model_best.pth', src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none')
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_train.h5
# ModelNet40_OOD - split: train, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# SR1 train data len: 2378
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Src is SR1
#
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {4: 0, 8: 1, 7: 2, 12: 3, 13: 4}, num samples: 1255
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {10: 0, 14: 1, 5: 2, 6: 3, 9: 2}, num samples: 788
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {0: 404, 1: 404, 2: 404, 3: 404, 11: 404}, num samples: 847
# dgcnn k: 20
# dgcnn emb_dims: 1024
# Clf - feature encoder: DGCNN
# Clf Head - num classes: 5, input dim: 2048, act: leakyrelu, dropout: 0.5
# Model params count: 1.8003 M
# Load weights:  <All keys matched successfully>
# 100% 1255/1255 [00:25<00:00, 48.95it/s]
# 100% 788/788 [00:16<00:00, 48.84it/s]
# 100% 847/847 [00:17<00:00, 48.03it/s]
#
# ################################################################################
# Computing OOD metrics with MSP normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.7091633466135459, Clf Bal Acc: 0.714984156675784
# SRC->TAR1:      AUROC: 0.7069, FPR95: 0.8693, AUPR_IN: 0.8161, AUPR_OUT: 0.5561
# SRC->TAR2:      AUROC: 0.7499, FPR95: 0.8489, AUPR_IN: 0.8379, AUPR_OUT: 0.6278
# SRC->TAR1+TAR2: AUROC: 0.7291, FPR95: 0.8587, AUPR_IN: 0.7247, AUPR_OUT: 0.7416
# to spreadsheet: 0.7068649260824722,0.8692893401015228,0.8160787680629035,0.5561166178483924,0.7498821714323344,0.8488783943329398,0.8379178361843775,0.62778128910012,0.7291497008906271,0.8587155963302753,0.7247106496735096,0.7415754950062703
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with MLS normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.7091633466135459, Clf Bal Acc: 0.714984156675784
# SRC->TAR1:      AUROC: 0.6799, FPR95: 0.9074, AUPR_IN: 0.8050, AUPR_OUT: 0.5136
# SRC->TAR2:      AUROC: 0.7244, FPR95: 0.8465, AUPR_IN: 0.8244, AUPR_OUT: 0.5939
# SRC->TAR1+TAR2: AUROC: 0.7029, FPR95: 0.8758, AUPR_IN: 0.7094, AUPR_OUT: 0.7120
# to spreadsheet: 0.6798966570267155,0.9073604060913706,0.8049555225724223,0.5135924418318185,0.7243611151615498,0.846517119244392,0.8244083760891222,0.5938892057497499,0.7029311500176664,0.8758409785932721,0.7094120979262946,0.7120036397493533
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with entropy normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.7091633466135459, Clf Bal Acc: 0.714984156675784
# SRC->TAR1:      AUROC: 0.7016, FPR95: 0.8832, AUPR_IN: 0.8141, AUPR_OUT: 0.5465
# SRC->TAR2:      AUROC: 0.7483, FPR95: 0.8276, AUPR_IN: 0.8375, AUPR_OUT: 0.6288
# SRC->TAR1+TAR2: AUROC: 0.7258, FPR95: 0.8544, AUPR_IN: 0.7233, AUPR_OUT: 0.7385
# to spreadsheet: 0.7016320504782899,0.883248730964467,0.8141214189737027,0.5465163309016955,0.748321001707456,0.8276269185360094,0.8374616494700843,0.6287961837908931,0.7258189261303409,0.854434250764526,0.7233430989522631,0.7385019320167725
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with distance from train features...
#   0% 0/2378 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 2378/2378 [00:16<00:00, 146.79it/s]
# 100% 1255/1255 [00:25<00:00, 48.43it/s]
# 100% 788/788 [00:16<00:00, 48.49it/s]
# 100% 847/847 [00:17<00:00, 48.62it/s]
# Euclidean distances in a non-normalized space:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6573705179282868, Clf Bal Acc: 0.6501686984197862
# SRC->TAR1:      AUROC: 0.5152, FPR95: 0.9619, AUPR_IN: 0.6609, AUPR_OUT: 0.3781
# SRC->TAR2:      AUROC: 0.6775, FPR95: 0.8158, AUPR_IN: 0.7456, AUPR_OUT: 0.5719
# SRC->TAR1+TAR2: AUROC: 0.5993, FPR95: 0.8862, AUPR_IN: 0.5445, AUPR_OUT: 0.6453
# to spreadsheet: 0.5152344934980888,0.9619289340101523,0.6608950373336981,0.3780667777935378,0.6775086195948201,0.8158205430932703,0.7455612603850509,0.5719219399138175,0.5992994383322977,0.8862385321100917,0.544504440287241,0.6453186479946362
#
# Euclidean distances with prototypes:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.21274900398406374, Clf Bal Acc: 0.2
# SRC->TAR1:      AUROC: 0.5653, FPR95: 0.9467, AUPR_IN: 0.6524, AUPR_OUT: 0.4280
# SRC->TAR2:      AUROC: 0.6637, FPR95: 0.8288, AUPR_IN: 0.6924, AUPR_OUT: 0.5761
# SRC->TAR1+TAR2: AUROC: 0.6163, FPR95: 0.8856, AUPR_IN: 0.5069, AUPR_OUT: 0.6689
# to spreadsheet: 0.5653199385200316,0.9467005076142132,0.6523663134035441,0.42800195615723585,0.6637379643174646,0.8288075560802833,0.6924119686571193,0.5761461442066014,0.6163046894988852,0.8856269113149847,0.5068951995191567,0.6689120269231976
#
# Cosine similarities on the hypersphere:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6605577689243027, Clf Bal Acc: 0.6477841673216261
# SRC->TAR1:      AUROC: 0.6269, FPR95: 0.9404, AUPR_IN: 0.7549, AUPR_OUT: 0.4576
# SRC->TAR2:      AUROC: 0.6880, FPR95: 0.8902, AUPR_IN: 0.7684, AUPR_OUT: 0.5517
# SRC->TAR1+TAR2: AUROC: 0.6585, FPR95: 0.9144, AUPR_IN: 0.6257, AUPR_OUT: 0.6716
# to spreadsheet: 0.6269338888102414,0.9403553299492385,0.7548999632136841,0.4575537632600256,0.687958908168977,0.8902007083825265,0.768362919870561,0.5516575524136604,0.6585474615300266,0.9143730886850153,0.6256621555341091,0.6715653288350873
#
# Cosine similarities with prototypes:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.21274900398406374, Clf Bal Acc: 0.2
# SRC->TAR1:      AUROC: 0.5718, FPR95: 0.8896, AUPR_IN: 0.6475, AUPR_OUT: 0.4653
# SRC->TAR2:      AUROC: 0.6317, FPR95: 0.8867, AUPR_IN: 0.6882, AUPR_OUT: 0.5086
# SRC->TAR1+TAR2: AUROC: 0.6028, FPR95: 0.8881, AUPR_IN: 0.5014, AUPR_OUT: 0.6534
# to spreadsheet: 0.5718263999838211,0.8895939086294417,0.6474978176226565,0.46531398412816427,0.6316801271890008,0.8866587957497049,0.688207138044681,0.5085670088780543,0.6028331932209997,0.8880733944954129,0.5013933805685193,0.6534089345311554
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with ODIN normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [01:10<00:00, 17.83it/s]
# 100% 788/788 [00:43<00:00, 17.92it/s]
# 100% 847/847 [00:47<00:00, 17.92it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6801, FPR95: 0.9061, AUPR_IN: 0.8055, AUPR_OUT: 0.5134
# SRC->TAR2:      AUROC: 0.7239, FPR95: 0.8453, AUPR_IN: 0.8244, AUPR_OUT: 0.5930
# SRC->TAR1+TAR2: AUROC: 0.7028, FPR95: 0.8746, AUPR_IN: 0.7100, AUPR_OUT: 0.7116
# to spreadsheet: 0.680067041478755,0.9060913705583756,0.8055437956477705,0.5134244257671116,0.7238949749996473,0.8453364817001181,0.8243507467204801,0.5930421625669797,0.7027717874678654,0.8746177370030581,0.7099930512194093,0.7115880909555161
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with Energy normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [00:28<00:00, 44.53it/s]
# 100% 788/788 [00:17<00:00, 44.49it/s]
# 100% 847/847 [00:19<00:00, 44.35it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6768, FPR95: 0.9175, AUPR_IN: 0.8038, AUPR_OUT: 0.5016
# SRC->TAR2:      AUROC: 0.7201, FPR95: 0.8560, AUPR_IN: 0.8217, AUPR_OUT: 0.5810
# SRC->TAR1+TAR2: AUROC: 0.6992, FPR95: 0.8856, AUPR_IN: 0.7068, AUPR_OUT: 0.7027
# to spreadsheet: 0.676806479665096,0.9175126903553299,0.8037522048796493,0.501635254138095,0.7201127014962582,0.8559622195985832,0.821732954438461,0.5810221400354227,0.6992409566626461,0.8856269113149847,0.7068164907249819,0.702737854454186
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with GradNorm normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [00:43<00:00, 28.95it/s]
# 100% 788/788 [00:27<00:00, 28.70it/s]
# 100% 847/847 [00:29<00:00, 28.80it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.7278, FPR95: 0.9036, AUPR_IN: 0.8340, AUPR_OUT: 0.5440
# SRC->TAR2:      AUROC: 0.7182, FPR95: 0.8819, AUPR_IN: 0.8248, AUPR_OUT: 0.5587
# SRC->TAR1+TAR2: AUROC: 0.7228, FPR95: 0.8924, AUPR_IN: 0.7301, AUPR_OUT: 0.7105
# to spreadsheet: 0.7278014844176594,0.9035532994923858,0.834044518012064,0.544020760282623,0.7182406148722701,0.8819362455726092,0.8247562953843148,0.5586876404606845,0.7228485446592833,0.8923547400611621,0.7301449840995629,0.7105300661850183
# ################################################################################
#
# ################################################################################
# Building React validation loader...
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# React Val - SR1 data len: 340
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 340/340 [00:03<00:00, 103.11it/s]
# t = 3.3946
# Computing OOD metrics with React (+Energy) normality score, ID-dependent threshold (=3.3946)...
# React - using SR1 test to compute threshold
# 100% 1255/1255 [00:28<00:00, 44.60it/s]
# 100% 788/788 [00:17<00:00, 44.66it/s]
# 100% 847/847 [00:19<00:00, 44.12it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6470, FPR95: 0.9162, AUPR_IN: 0.7753, AUPR_OUT: 0.4839
# SRC->TAR2:      AUROC: 0.7089, FPR95: 0.8560, AUPR_IN: 0.8048, AUPR_OUT: 0.5784
# SRC->TAR1+TAR2: AUROC: 0.6791, FPR95: 0.8850, AUPR_IN: 0.6715, AUPR_OUT: 0.6941
# to spreadsheet: 0.6469538091289664,0.916243654822335,0.7753220534398704,0.4838801037059905,0.7089319228399272,0.8559622195985832,0.8047506763651588,0.5783739904286784,0.6790611255284672,0.8850152905198777,0.6714869513416521,0.6940896685254206
# ################################################################################
