# %% [markdown]
# <a href="https://colab.research.google.com/github/yurnero14/AML_2023_2024/blob/main/SemNovProj_23_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cu121

# %%
# installing pointnet++
# !pip install ninja
# !git clone https://github.com/erikwijmans/Pointnet2_PyTorch
# %cd /content/Pointnet2_PyTorch
# !python setup.py install

# moving to root directory
# %cd ..
# Out:
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.1
# Cloning into 'Pointnet2_PyTorch'...
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 706 (delta 0), reused 1 (delta 0), pack-reused 703
# Receiving objects: 100% (706/706), 976.27 KiB | 6.22 MiB/s, done.
# Resolving deltas: 100% (391/391), done.
# /content/Pointnet2_PyTorch
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating pointnet2.egg-info
# writing pointnet2.egg-info/PKG-INFO
# writing dependency_links to pointnet2.egg-info/dependency_links.txt
# writing requirements to pointnet2.egg-info/requires.txt
# writing top-level names to pointnet2.egg-info/top_level.txt
# writing manifest file 'pointnet2.egg-info/SOURCES.txt'
# reading manifest file 'pointnet2.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'pointnet2.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pointnet2
# copying pointnet2/__init__.py -> build/lib/pointnet2
# copying pointnet2/train.py -> build/lib/pointnet2
# copying pointnet2/_version.py -> build/lib/pointnet2
# creating build/lib/pointnet2/models
# copying pointnet2/models/pointnet2_msg_cls.py -> build/lib/pointnet2/models
# copying pointnet2/models/__init__.py -> build/lib/pointnet2/models
# copying pointnet2/models/pointnet2_ssg_sem.py -> build/lib/pointnet2/models
# copying pointnet2/models/pointnet2_ssg_cls.py -> build/lib/pointnet2/models
# copying pointnet2/models/pointnet2_msg_sem.py -> build/lib/pointnet2/models
# creating build/lib/pointnet2/data
# copying pointnet2/data/__init__.py -> build/lib/pointnet2/data
# copying pointnet2/data/Indoor3DSemSegLoader.py -> build/lib/pointnet2/data
# copying pointnet2/data/ModelNet40Loader.py -> build/lib/pointnet2/data
# copying pointnet2/data/data_utils.py -> build/lib/pointnet2/data
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pointnet2
# copying build/lib/pointnet2/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2
# creating build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_msg_cls.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_ssg_sem.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_ssg_cls.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/models/pointnet2_msg_sem.py -> build/bdist.linux-x86_64/egg/pointnet2/models
# copying build/lib/pointnet2/train.py -> build/bdist.linux-x86_64/egg/pointnet2
# copying build/lib/pointnet2/_version.py -> build/bdist.linux-x86_64/egg/pointnet2
# creating build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/__init__.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/Indoor3DSemSegLoader.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/ModelNet40Loader.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# copying build/lib/pointnet2/data/data_utils.py -> build/bdist.linux-x86_64/egg/pointnet2/data
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_msg_cls.py to pointnet2_msg_cls.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_ssg_sem.py to pointnet2_ssg_sem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_ssg_cls.py to pointnet2_ssg_cls.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/models/pointnet2_msg_sem.py to pointnet2_msg_sem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/train.py to train.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/_version.py to _version.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/Indoor3DSemSegLoader.py to Indoor3DSemSegLoader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/ModelNet40Loader.py to ModelNet40Loader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pointnet2/data/data_utils.py to data_utils.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pointnet2.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# pointnet2.data.__pycache__.Indoor3DSemSegLoader.cpython-310: module references __file__
# pointnet2.data.__pycache__.ModelNet40Loader.cpython-310: module references __file__
# creating dist
# creating 'dist/pointnet2-3.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pointnet2-3.0.0-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/pointnet2-3.0.0-py3.10.egg
# Extracting pointnet2-3.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding pointnet2 3.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/pointnet2-3.0.0-py3.10.egg
# Processing dependencies for pointnet2==3.0.0
# Searching for pytorch-lightning==0.7.1
# Reading https://pypi.org/simple/pytorch-lightning/
# Downloading https://files.pythonhosted.org/packages/61/9e/db4e1e3036e045a25d5c37617ded31a673a61f4befc62c5231818810b3a7/pytorch-lightning-0.7.1.tar.gz#sha256=d1848e0170b2eb88e25a6bc011bbecbbc0e1fcd47edb2d2b26070e36755f5b57
# Best match: pytorch-lightning 0.7.1
# Processing pytorch-lightning-0.7.1.tar.gz
# Writing /tmp/easy_install-4azhn6u3/pytorch-lightning-0.7.1/setup.cfg
# Running pytorch-lightning-0.7.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-4azhn6u3/pytorch-lightning-0.7.1/egg-dist-tmp-6qhejmbt
# Partial import of `torchlightning` during the build process.
# /usr/local/lib/python3.10/dist-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
# !!
#
#         ********************************************************************************
#         The license_file parameter is deprecated, use license_files instead.
#
#         This deprecation is overdue, please update your project and remove deprecated
#         calls to avoid build errors in the future.
#
#         See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#         ********************************************************************************
#
# !!
#   parsed = self.parsers.get(option_name, lambda x: x)(value)
# warning: no directories found matching 'wheelhouse'
# warning: no previously-included files matching '*.py[cod]' found under directory '__pycache__'
# warning: no previously-included files matching '*.orig' found under directory '__pycache__'
# warning: no previously-included files found matching '*.sh'
# warning: no previously-included files found matching '*.toml'
# warning: no previously-included files found matching '*.svg'
# warning: no previously-included files matching '*' found under directory 'tests'
# warning: no previously-included files matching '*' found under directory 'site'
# warning: no previously-included files found matching 'tests'
# warning: no previously-included files found matching 'docs'
# warning: no previously-included files found matching '*.yml'
# no previously-included directories found matching '.git'
# no previously-included directories found matching '.github'
# no previously-included directories found matching '.circleci'
# no previously-included directories found matching 'notebook*'
# no previously-included directories found matching 'temp*'
# no previously-included directories found matching 'test*'
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'pl_examples.full_examples.semantic_segmentation' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'pl_examples.full_examples.semantic_segmentation' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'pl_examples.full_examples.semantic_segmentation' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'pl_examples.full_examples.semantic_segmentation' to be distributed and are
#         already explicitly excluding 'pl_examples.full_examples.semantic_segmentation' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:201: _Warning: Package 'pl_examples.full_examples.semantic_segmentation.models.unet' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'pl_examples.full_examples.semantic_segmentation.models.unet' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'pl_examples.full_examples.semantic_segmentation.models.unet' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'pl_examples.full_examples.semantic_segmentation.models.unet' to be distributed and are
#         already explicitly excluding 'pl_examples.full_examples.semantic_segmentation.models.unet' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# Adding pytorch-lightning 0.7.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/pytorch_lightning-0.7.1-py3.10.egg
# Searching for hydra-core==0.11.3
# Reading https://pypi.org/simple/hydra-core/
# Downloading https://files.pythonhosted.org/packages/28/2f/e8dbf1266062d4041cbdcd725cb91210d9811aefb9cdf5fc04cb381bf9b9/hydra_core-0.11.3-py3-none-any.whl#sha256=43ef27b4a32a70cbf566b10bd198def5c5d03cab212d4ea49e744aeb0c14a6b7
# Best match: hydra-core 0.11.3
# Processing hydra_core-0.11.3-py3-none-any.whl
# Installing hydra_core-0.11.3-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding hydra-core 0.11.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/hydra_core-0.11.3-py3.10.egg
# Searching for omegaconf<1.5,>=1.4
# Reading https://pypi.org/simple/omegaconf/
# Downloading https://files.pythonhosted.org/packages/2f/53/d285f1faa36eca666f6d04ac17c5f3a9e72cedaeb530e663fdc025209780/omegaconf-1.4.1-py3-none-any.whl#sha256=01c9f93c3578dce7d42ce06f3d1305437322234ccc1accfc71d344d5e17413a1
# Best match: omegaconf 1.4.1
# Processing omegaconf-1.4.1-py3-none-any.whl
# Installing omegaconf-1.4.1-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding omegaconf 1.4.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/omegaconf-1.4.1-py3.10.egg
# Searching for future==0.18.3
# Best match: future 0.18.3
# Adding future 0.18.3 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard==2.15.1
# Best match: tensorboard 2.15.1
# Adding tensorboard 2.15.1 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torch==2.1.0+cu121
# Best match: torch 2.1.0+cu121
# Adding torch 2.1.0+cu121 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for werkzeug==3.0.1
# Best match: werkzeug 3.0.1
# Adding werkzeug 3.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Markdown==3.5.2
# Best match: Markdown 3.5.2
# Adding Markdown 3.5.2 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth-oauthlib==1.2.0
# Best match: google-auth-oauthlib 1.2.0
# Adding google-auth-oauthlib 1.2.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth==2.27.0
# Best match: google-auth 2.27.0
# Adding google-auth 2.27.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for grpcio==1.60.1
# Best match: grpcio 1.60.1
# Adding grpcio 1.60.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for triton==2.1.0
# Best match: triton 2.1.0
# Adding triton 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fsspec==2023.6.0
# Best match: fsspec 2023.6.0
# Adding fsspec 2023.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Jinja2==3.1.3
# Best match: Jinja2 3.1.3
# Adding Jinja2 3.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for networkx==3.2.1
# Best match: networkx 3.2.1
# Adding networkx 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for typing-extensions==4.9.0
# Best match: typing-extensions 4.9.0
# Adding typing-extensions 4.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for filelock==3.13.1
# Best match: filelock 3.13.1
# Adding filelock 3.13.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.5
# Best match: MarkupSafe 2.1.5
# Adding MarkupSafe 2.1.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2024.2.2
# Best match: certifi 2024.2.2
# Adding certifi 2024.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1-modules==0.3.0
# Best match: pyasn1-modules 0.3.0
# Adding pyasn1-modules 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cachetools==5.3.2
# Best match: cachetools 5.3.2
# Adding cachetools 5.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1==0.5.1
# Best match: pyasn1 0.5.1
# Adding pyasn1 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for pointnet2==3.0.0
# /content

# %%
# install minimal requirements (pytorch is already installed in colab)
# !pip install timm==0.5.4 wandb tqdm h5py==3.6.0 protobuf==3.20.1 lmdb==1.2.1 msgpack-numpy==0.4.7.1 scikit-learn
# Out:
# Requirement already satisfied: timm==0.5.4 in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: h5py==3.6.0 in /usr/local/lib/python3.10/dist-packages (3.6.0)
# Requirement already satisfied: protobuf==3.20.1 in /usr/local/lib/python3.10/dist-packages (3.20.1)
# Requirement already satisfied: lmdb==1.2.1 in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: msgpack-numpy==0.4.7.1 in /usr/local/lib/python3.10/dist-packages (0.4.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (0.16.0+cu121)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py==3.6.0) (1.23.5)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from msgpack-numpy==0.4.7.1) (1.0.7)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.41)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.40.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.5.4) (9.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)

# %%
# made a new repo for you starting from 3DOS with modifications to help you running the code with colab.
# !git clone https://github.com/antoalli/SemNov_AML_DAAI_23-24
# Out:
# Cloning into 'SemNov_AML_DAAI_23-24'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 160 (delta 17), reused 14 (delta 14), pack-reused 134
# Receiving objects: 100% (160/160), 135.45 KiB | 2.51 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
# !ls
# Out:
# Pointnet2_PyTorch  sample_data	SemNov_AML_DAAI_23-24

# %%
# Move to the project directory after Git clone
# %cd /content/SemNov_AML_DAAI_23-24
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
# !ls /content/SemNov_AML_DAAI_23-24
# Out:
# base_args.py  classifiers  docs		     models		README.md	  supcon
# cfgs	      datasets	   download_data.sh  pointnet2_ops_lib	requirements.txt  utils

# %%
# check we're in project directory (should be SemNov_AML_DAAI_23)
# !pwd
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
# !sh download_data.sh
# Out:
# Downloading data in /content/SemNov_AML_DAAI_23-24/3D_OS_release_data
# ============Downloading ModelNet40 + OOD Splits in
# --2024-02-13 11:22:31--  https://www.dropbox.com/s/c2x3h59nxprjs21/modelnet40_normal_resampled.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.64.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.64.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar [following]
# --2024-02-13 11:22:32--  https://www.dropbox.com/s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com/cd/0/get/CNPy6aDVBMxGZPO0wmBde0DWe36in62IFtMPV7KBq6LKTonNURaS7Pk-9yG4CiRsc8gkqcsH6Yb-FvNq2XwR4RwIN3BDHSF21DD7XDpcyMSbsvqKv4bSiZO3y5GRaaVU_UFXITpF80ZstVX3n8Rl_saj/file?dl=1# [following]
# --2024-02-13 11:22:33--  https://uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com/cd/0/get/CNPy6aDVBMxGZPO0wmBde0DWe36in62IFtMPV7KBq6LKTonNURaS7Pk-9yG4CiRsc8gkqcsH6Yb-FvNq2XwR4RwIN3BDHSF21DD7XDpcyMSbsvqKv4bSiZO3y5GRaaVU_UFXITpF80ZstVX3n8Rl_saj/file?dl=1
# Resolving uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com (uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com (uc257671ba2a493a88daf3bbb6d6.dl-eu.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7599001600 (7.1G) [application/binary]
# Saving to: ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_modelnet40_normal_resampled.tar’
#
# /content/SemNov_AML 100%[===================>]   7.08G  16.7MB/s    in 6m 16s
#
# 2024-02-13 11:28:50 (19.3 MB/s) - ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_modelnet40_normal_resampled.tar’ saved [7599001600/7599001600]
#
# ============
# ============Downloading ScanObjectNN in
# --2024-02-13 11:29:44--  https://www.dropbox.com/s/gu0p3rych1k26b7/ScanObjectNN.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/gu0p3rych1k26b7/ScanObjectNN.tar [following]
# --2024-02-13 11:29:44--  https://www.dropbox.com/s/dl/gu0p3rych1k26b7/ScanObjectNN.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com/cd/0/get/CNMfwbTzu3xKktJxmcHHlsSxvJmDIrtSm4zYaex-LfXN-XSK7WK5AIyOk_KaO6a2bPsQSPEyuCmc4DDPhdoRCcIUX5zqY_1s11Kg7haxb4d28YCWkoPcPJBE7HkBSZRiKQKwXUfN4meNX3ohcjB7PCnH/file?dl=1# [following]
# --2024-02-13 11:29:44--  https://uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com/cd/0/get/CNMfwbTzu3xKktJxmcHHlsSxvJmDIrtSm4zYaex-LfXN-XSK7WK5AIyOk_KaO6a2bPsQSPEyuCmc4DDPhdoRCcIUX5zqY_1s11Kg7haxb4d28YCWkoPcPJBE7HkBSZRiKQKwXUfN4meNX3ohcjB7PCnH/file?dl=1
# Resolving uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com (uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com)... 162.125.3.15, 2620:100:6024:15::a27d:440f
# Connecting to uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com (uc50502c38f77935a11f097005db.dl-eu.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623662080 (2.4G) [application/binary]
# Saving to: ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_ScanObjectNN.tar’
#
# /content/SemNov_AML 100%[===================>]   2.44G  17.0MB/s    in 1m 52s
#
# 2024-02-13 11:31:38 (22.3 MB/s) - ‘/content/SemNov_AML_DAAI_23-24/3D_OS_release_data/tmp_ScanObjectNN.tar’ saved [2623662080/2623662080]
#
# ============
# Finished

# %%
# example: train a DGCNN classifier on SR1 (Synth->Real) - read docs + 3DOS paper!
# we use wandb for logging - you've to make a wandb account to check loss curves or you can choose "Don't visualize my results"
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --epochs 50 --exp_name DGCNN_CE_SR1_morpheus_sgd --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_Disc
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# training...
# ******************************
# 0/1 process initialized.
#
# 0/1 arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='train', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=50, batch_size=64, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path=None, src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none', log_dir='outputs/DGCNN_CE_SR1_morpheus_sgd', tb_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/tb-logs', models_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/models', backup_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/backup-code').
#
# ******************************
# Arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='train', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=50, batch_size=64, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path=None, src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none', log_dir='outputs/DGCNN_CE_SR1_morpheus_sgd', tb_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/tb-logs', models_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/models', backup_dir='outputs/DGCNN_CE_SR1_morpheus_sgd/backup-code')
# Config: {'optimizer': {'type': 'sgd', 'skip_wd': [], 'weight_decay': 0.0001, 'kwargs': {'lr': 0.1, 'momentum': 0.9}}, 'scheduler': {'type': 'CosLR', 'kwargs': {'t_initial': 250, 'cycle_limit': 1, 'lr_min': 0.0001}}, 'model': {'ENCO_NAME': 'DGCNN', 'k': 20, 'emb_dims': 1024, 'dropout': 0.5, 'cla_input_dim': 2048, 'act': 'leakyrelu'}}
# World size: 1
#
# wandb: Currently logged in as: yurnero. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in /content/SemNov_AML_DAAI_23-24/wandb/run-20240213_113951-evze60yp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run DGCNN_CE_SR1_morpheus_sgd
# wandb: ⭐️ View project at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc
# wandb: 🚀 View run at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/runs/evze60yp
# Train transforms: [<utils.data_utils.PointcloudToTensor object at 0x7fa1cdfe39d0>, <utils.data_utils.RandomSample object at 0x7fa1cdb32320>, <utils.data_utils.AugmScale object at 0x7fa1cdb325f0>, <utils.data_utils.AugmRotate object at 0x7fa1cd788400>, <utils.data_utils.AugmRotatePerturbation object at 0x7fa1cd7bf4f0>, <utils.data_utils.AugmTranslate object at 0x7fa1cd73a800>, <utils.data_utils.AugmJitter object at 0x7fa1cd73a7d0>]
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_train.h5
# ModelNet40_OOD - split: train, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# SR1 train_data len: 2378
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# SR1 train synset: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# Source: SR1
# Num training classes: 5
# dgcnn k: 20
# dgcnn emb_dims: 1024
# Clf - feature encoder: DGCNN
# Clf Head - num classes: 5, input dim: 2048, act: leakyrelu, dropout: 0.5
# Model:
# Classifier(
#   (enco): DGCNN(
#     (conv1): Sequential(
#       (0): Conv2d(6, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv4): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (conv5): Sequential(
#       (0): Conv1d(512, 1024, kernel_size=(1,), stride=(1,), bias=False)
#       (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (penultimate): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=False)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (head): Sequential(
#     (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.95it/s]
# Test [21/50]	Acc: 0.9625, Bal Acc: 0.9157
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-22/50], rank: [1/1], Loss: 0.0446, Loss avg: 0.0436, lr: 0.098271, BT: 0.85, DT: 0.00
# it: [20/37-22/50], rank: [1/1], Loss: 0.0194, Loss avg: 0.0414, lr: 0.098271, BT: 0.85, DT: 0.00
# it: [30/37-22/50], rank: [1/1], Loss: 0.0148, Loss avg: 0.0482, lr: 0.098271, BT: 0.85, DT: 0.00
# Train [22/50]	rank: [1/1], Loss: 0.0494, Acc: 0.9823, Bal Acc: 0.9649, BT: 0.86, DT: 0.02,  epoch time: 32.03
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.95it/s]
# Test [22/50]	Acc: 0.9781, Bal Acc: 0.9582
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-23/50], rank: [1/1], Loss: 0.0538, Loss avg: 0.0694, lr: 0.098103, BT: 0.85, DT: 0.00
# it: [20/37-23/50], rank: [1/1], Loss: 0.0058, Loss avg: 0.0673, lr: 0.098103, BT: 0.85, DT: 0.00
# it: [30/37-23/50], rank: [1/1], Loss: 0.0843, Loss avg: 0.0611, lr: 0.098103, BT: 0.85, DT: 0.00
# Train [23/50]	rank: [1/1], Loss: 0.0611, Acc: 0.9827, Bal Acc: 0.9610, BT: 0.86, DT: 0.01,  epoch time: 31.99
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.37it/s]
# Test [23/50]	Acc: 0.9719, Bal Acc: 0.9389
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-24/50], rank: [1/1], Loss: 0.1874, Loss avg: 0.0987, lr: 0.097928, BT: 0.85, DT: 0.00
# it: [20/37-24/50], rank: [1/1], Loss: 0.0605, Loss avg: 0.0871, lr: 0.097928, BT: 0.85, DT: 0.00
# it: [30/37-24/50], rank: [1/1], Loss: 0.0490, Loss avg: 0.0739, lr: 0.097928, BT: 0.85, DT: 0.00
# Train [24/50]	rank: [1/1], Loss: 0.0703, Acc: 0.9789, Bal Acc: 0.9568, BT: 0.86, DT: 0.01,  epoch time: 31.90
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.95it/s]
# Test [24/50]	Acc: 0.9625, Bal Acc: 0.9427
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-25/50], rank: [1/1], Loss: 0.0377, Loss avg: 0.0480, lr: 0.097745, BT: 0.85, DT: 0.00
# it: [20/37-25/50], rank: [1/1], Loss: 0.0569, Loss avg: 0.0628, lr: 0.097745, BT: 0.85, DT: 0.00
# it: [30/37-25/50], rank: [1/1], Loss: 0.0167, Loss avg: 0.0613, lr: 0.097745, BT: 0.85, DT: 0.00
# Train [25/50]	rank: [1/1], Loss: 0.0564, Acc: 0.9823, Bal Acc: 0.9675, BT: 0.87, DT: 0.02,  epoch time: 32.29
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.97it/s]
# Test [25/50]	Acc: 0.9750, Bal Acc: 0.9480
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-26/50], rank: [1/1], Loss: 0.0119, Loss avg: 0.0313, lr: 0.097555, BT: 0.85, DT: 0.00
# it: [20/37-26/50], rank: [1/1], Loss: 0.0068, Loss avg: 0.0483, lr: 0.097555, BT: 0.85, DT: 0.00
# it: [30/37-26/50], rank: [1/1], Loss: 0.0167, Loss avg: 0.0415, lr: 0.097555, BT: 0.85, DT: 0.00
# Train [26/50]	rank: [1/1], Loss: 0.0440, Acc: 0.9840, Bal Acc: 0.9602, BT: 0.86, DT: 0.02,  epoch time: 32.00
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.97it/s]
# Test [26/50]	Acc: 0.9781, Bal Acc: 0.9672
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-27/50], rank: [1/1], Loss: 0.0375, Loss avg: 0.0380, lr: 0.097358, BT: 0.85, DT: 0.00
# it: [20/37-27/50], rank: [1/1], Loss: 0.1006, Loss avg: 0.0352, lr: 0.097358, BT: 0.85, DT: 0.00
# it: [30/37-27/50], rank: [1/1], Loss: 0.0410, Loss avg: 0.0373, lr: 0.097358, BT: 0.85, DT: 0.00
# Train [27/50]	rank: [1/1], Loss: 0.0471, Acc: 0.9852, Bal Acc: 0.9701, BT: 0.86, DT: 0.02,  epoch time: 32.06
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.97it/s]
# Test [27/50]	Acc: 0.9656, Bal Acc: 0.9355
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-28/50], rank: [1/1], Loss: 0.0126, Loss avg: 0.0593, lr: 0.097152, BT: 0.85, DT: 0.00
# it: [20/37-28/50], rank: [1/1], Loss: 0.0235, Loss avg: 0.0516, lr: 0.097152, BT: 0.85, DT: 0.00
# it: [30/37-28/50], rank: [1/1], Loss: 0.0506, Loss avg: 0.0497, lr: 0.097152, BT: 0.85, DT: 0.00
# Train [28/50]	rank: [1/1], Loss: 0.0462, Acc: 0.9835, Bal Acc: 0.9633, BT: 0.88, DT: 0.02,  epoch time: 32.71
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.57it/s]
# Test [28/50]	Acc: 0.8844, Bal Acc: 0.8963
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-29/50], rank: [1/1], Loss: 0.0086, Loss avg: 0.0599, lr: 0.096940, BT: 0.85, DT: 0.00
# it: [20/37-29/50], rank: [1/1], Loss: 0.0310, Loss avg: 0.0545, lr: 0.096940, BT: 0.85, DT: 0.00
# it: [30/37-29/50], rank: [1/1], Loss: 0.1017, Loss avg: 0.0602, lr: 0.096940, BT: 0.85, DT: 0.00
# Train [29/50]	rank: [1/1], Loss: 0.0560, Acc: 0.9789, Bal Acc: 0.9544, BT: 0.87, DT: 0.02,  epoch time: 32.07
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
#   warnings.warn(_create_warning_msg(
# it: [10/37-41/50], rank: [1/1], Loss: 0.0108, Loss avg: 0.0290, lr: 0.093822, BT: 0.85, DT: 0.00
# it: [20/37-41/50], rank: [1/1], Loss: 0.0409, Loss avg: 0.0304, lr: 0.093822, BT: 0.85, DT: 0.00
# it: [30/37-41/50], rank: [1/1], Loss: 0.0083, Loss avg: 0.0338, lr: 0.093822, BT: 0.85, DT: 0.00
# Train [41/50]	rank: [1/1], Loss: 0.0394, Acc: 0.9882, Bal Acc: 0.9788, BT: 0.88, DT: 0.03,  epoch time: 32.48
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.77it/s]
# Test [41/50]	Acc: 0.9563, Bal Acc: 0.9199
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-42/50], rank: [1/1], Loss: 0.0163, Loss avg: 0.0375, lr: 0.093516, BT: 0.85, DT: 0.00
# it: [20/37-42/50], rank: [1/1], Loss: 0.1247, Loss avg: 0.0342, lr: 0.093516, BT: 0.85, DT: 0.00
# it: [30/37-42/50], rank: [1/1], Loss: 0.1317, Loss avg: 0.0403, lr: 0.093516, BT: 0.85, DT: 0.00
# Train [42/50]	rank: [1/1], Loss: 0.0411, Acc: 0.9852, Bal Acc: 0.9705, BT: 0.86, DT: 0.02,  epoch time: 32.06
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.82it/s]
# Test [42/50]	Acc: 0.9656, Bal Acc: 0.9766
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-43/50], rank: [1/1], Loss: 0.0274, Loss avg: 0.0287, lr: 0.093203, BT: 0.85, DT: 0.00
# it: [20/37-43/50], rank: [1/1], Loss: 0.0592, Loss avg: 0.0427, lr: 0.093203, BT: 0.85, DT: 0.01
# it: [30/37-43/50], rank: [1/1], Loss: 0.0930, Loss avg: 0.0387, lr: 0.093203, BT: 0.85, DT: 0.00
# Train [43/50]	rank: [1/1], Loss: 0.0429, Acc: 0.9869, Bal Acc: 0.9720, BT: 0.86, DT: 0.01,  epoch time: 31.94
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.87it/s]
# Test [43/50]	Acc: 0.9781, Bal Acc: 0.9850
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-44/50], rank: [1/1], Loss: 0.0409, Loss avg: 0.0240, lr: 0.092883, BT: 0.85, DT: 0.00
# it: [20/37-44/50], rank: [1/1], Loss: 0.0073, Loss avg: 0.0251, lr: 0.092883, BT: 0.85, DT: 0.01
# it: [30/37-44/50], rank: [1/1], Loss: 0.0066, Loss avg: 0.0257, lr: 0.092883, BT: 0.85, DT: 0.00
# Train [44/50]	rank: [1/1], Loss: 0.0257, Acc: 0.9907, Bal Acc: 0.9788, BT: 0.86, DT: 0.01,  epoch time: 31.96
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.35it/s]
# Test [44/50]	Acc: 0.9500, Bal Acc: 0.9349
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-45/50], rank: [1/1], Loss: 0.0327, Loss avg: 0.0532, lr: 0.092557, BT: 0.85, DT: 0.00
# it: [20/37-45/50], rank: [1/1], Loss: 0.0265, Loss avg: 0.0360, lr: 0.092557, BT: 0.85, DT: 0.00
# it: [30/37-45/50], rank: [1/1], Loss: 0.1185, Loss avg: 0.0375, lr: 0.092557, BT: 0.85, DT: 0.00
# Train [45/50]	rank: [1/1], Loss: 0.0348, Acc: 0.9878, Bal Acc: 0.9754, BT: 0.86, DT: 0.02,  epoch time: 32.04
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.78it/s]
# Test [45/50]	Acc: 0.9750, Bal Acc: 0.9743
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-46/50], rank: [1/1], Loss: 0.0074, Loss avg: 0.0309, lr: 0.092224, BT: 0.85, DT: 0.00
# it: [20/37-46/50], rank: [1/1], Loss: 0.0037, Loss avg: 0.0331, lr: 0.092224, BT: 0.85, DT: 0.00
# it: [30/37-46/50], rank: [1/1], Loss: 0.2195, Loss avg: 0.0370, lr: 0.092224, BT: 0.85, DT: 0.00
# Train [46/50]	rank: [1/1], Loss: 0.0343, Acc: 0.9873, Bal Acc: 0.9772, BT: 0.87, DT: 0.02,  epoch time: 32.32
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.77it/s]
# Test [46/50]	Acc: 0.9750, Bal Acc: 0.9560
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-47/50], rank: [1/1], Loss: 0.0177, Loss avg: 0.0367, lr: 0.091885, BT: 0.85, DT: 0.00
# it: [20/37-47/50], rank: [1/1], Loss: 0.0377, Loss avg: 0.0547, lr: 0.091885, BT: 0.85, DT: 0.00
# it: [30/37-47/50], rank: [1/1], Loss: 0.0229, Loss avg: 0.0538, lr: 0.091885, BT: 0.85, DT: 0.00
# Train [47/50]	rank: [1/1], Loss: 0.0543, Acc: 0.9827, Bal Acc: 0.9641, BT: 0.86, DT: 0.01,  epoch time: 31.93
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.90it/s]
# Test [47/50]	Acc: 0.9656, Bal Acc: 0.9215
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-48/50], rank: [1/1], Loss: 0.3250, Loss avg: 0.0538, lr: 0.091538, BT: 0.85, DT: 0.00
# it: [20/37-48/50], rank: [1/1], Loss: 0.0851, Loss avg: 0.0487, lr: 0.091538, BT: 0.85, DT: 0.00
# it: [30/37-48/50], rank: [1/1], Loss: 0.0331, Loss avg: 0.0433, lr: 0.091538, BT: 0.85, DT: 0.00
# Train [48/50]	rank: [1/1], Loss: 0.0399, Acc: 0.9886, Bal Acc: 0.9743, BT: 0.86, DT: 0.02,  epoch time: 32.07
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.71it/s]
# Test [48/50]	Acc: 0.9719, Bal Acc: 0.9732
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-49/50], rank: [1/1], Loss: 0.0040, Loss avg: 0.0407, lr: 0.091185, BT: 0.85, DT: 0.01
# it: [20/37-49/50], rank: [1/1], Loss: 0.0170, Loss avg: 0.0367, lr: 0.091185, BT: 0.85, DT: 0.00
# it: [30/37-49/50], rank: [1/1], Loss: 0.0027, Loss avg: 0.0317, lr: 0.091185, BT: 0.85, DT: 0.00
# Train [49/50]	rank: [1/1], Loss: 0.0345, Acc: 0.9882, Bal Acc: 0.9785, BT: 0.86, DT: 0.02,  epoch time: 32.06
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.39it/s]
# Test [49/50]	Acc: 0.9594, Bal Acc: 0.9250
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# it: [10/37-50/50], rank: [1/1], Loss: 0.0636, Loss avg: 0.0575, lr: 0.090826, BT: 0.85, DT: 0.00
# it: [20/37-50/50], rank: [1/1], Loss: 0.0057, Loss avg: 0.0598, lr: 0.090826, BT: 0.85, DT: 0.00
# it: [30/37-50/50], rank: [1/1], Loss: 0.0192, Loss avg: 0.0521, lr: 0.090826, BT: 0.85, DT: 0.00
# Train [50/50]	rank: [1/1], Loss: 0.0527, Acc: 0.9852, Bal Acc: 0.9688, BT: 0.86, DT: 0.01,  epoch time: 31.87
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 5/5 [00:01<00:00,  4.91it/s]
# Test [50/50]	Acc: 0.9688, Bal Acc: 0.9451
# Training finished - best test acc: 0.9812 at ep.: 39, time: 1723.9431324005127
# wandb:
# wandb: Run history:
# wandb:      test/ep_acc ▄▃▆▇▇▆▁▇▇██▇██▆▇▇██▇██▅██████▇██▇██▇████
# wandb:  test/ep_bal_acc ▁▂▆▇█▇▄▇▇█▇▇▇█▆▇▇█▇▇█▇▇█▇███▇▇▇█▇██▇█▇█▇
# wandb:       test/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:     train/ep_acc ▁▄▆▆▇▇▇▇▇▇█████▇████████████████████████
# wandb: train/ep_bal_acc ▁▃▅▆▇▇▇▇▇▇█▇▇██▇████████████████████████
# wandb:    train/ep_loss █▅▃▃▂▂▂▂▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    train/ep_time █▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:      train/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:         train/it ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:    train/it_loss █▆▂▂▁▂▃▂▁▂▂▁▂▁▁▂▂▁▂▁▁▂▁▁▁▁▂▁▁▁▁▁▁▂▁▁▃▃▁▁
# wandb:      train/it_lr ███████████▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▂▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:      test/ep_acc 0.96875
# wandb:  test/ep_bal_acc 0.94508
# wandb:       test/epoch 50
# wandb:     train/ep_acc 0.98522
# wandb: train/ep_bal_acc 0.96884
# wandb:    train/ep_loss 0.0527
# wandb:    train/ep_time 31.87186
# wandb:      train/epoch 50
# wandb:         train/it 1843
# wandb:    train/it_loss 0.01923
# wandb:      train/it_lr 0.09083
# wandb:
# wandb: 🚀 View run DGCNN_CE_SR1_morpheus_sgd at: https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/runs/evze60yp
# wandb: ️⚡ View job at https://wandb.ai/yurnero/AML_DAAI_proj23_24_Disc/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzOTQwOTc5Mw==/version_details/v1
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240213_113951-evze60yp/logs

# %%
# !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl
# Out:
# Collecting KNN-CUDA==0.2
#   Downloading https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (1.2.2)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from KNN-CUDA==0.2) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->KNN-CUDA==0.2) (2.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->KNN-CUDA==0.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->KNN-CUDA==0.2) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1.0->KNN-CUDA==0.2) (1.3.0)
# Installing collected packages: KNN-CUDA
# Successfully installed KNN-CUDA-0.2

# %%
# !python classifiers/trainer_cla_md.py --script_mode eval  --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1_morpheus_sgd --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24_Disc --ckpt_path /content/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1_morpheus_sgd/models/model_best.pth
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# out-of-distribution eval - Modelnet -> SONN ..
# Arguments: Namespace(local_rank=None, use_sync_bn=False, use_amp=False, script_mode='eval', config='cfgs/dgcnn-cla.yaml', seed=1, epochs=250, batch_size=1, num_workers=4, resume=None, apply_fix_cellphone=True, data_root='./3D_OS_release_data', checkpoints_dir='outputs', exp_name='DGCNN_CE_SR1_morpheus_sgd', eval_step=1, save_step=10, ckpt_path='/content/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1_morpheus_sgd/models/model_best.pth', src='SR1', sonn_split='main_split', sonn_h5_name='objectdataset.h5', augm_set='rw', grad_norm_clip=-1, num_points=1024, num_points_test=2048, wandb_name=None, wandb_group='md-2-sonn-augmCorr', wandb_proj='AML_DAAI_proj23_24_Disc', loss='CE', cs=False, cs_gan_lr=0.0002, cs_beta=0.1, save_feats=None, corruption=None, tar1='none', tar2='none')
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_train.h5
# ModelNet40_OOD - split: train, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# SR1 train data len: 2378
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Src is SR1
#
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {4: 0, 8: 1, 7: 2, 12: 3, 13: 4}, num samples: 1255
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {10: 0, 14: 1, 5: 2, 6: 3, 9: 2}, num samples: 788
# ScanObject - num_points: 2048, sonn_split: main_split, h5_suffix: objectdataset.h5, split: all, class_choice: {0: 404, 1: 404, 2: 404, 3: 404, 11: 404}, num samples: 847
# dgcnn k: 20
# dgcnn emb_dims: 1024
# Clf - feature encoder: DGCNN
# Clf Head - num classes: 5, input dim: 2048, act: leakyrelu, dropout: 0.5
# Model params count: 1.8003 M
# Load weights:  <All keys matched successfully>
# 100% 1255/1255 [00:24<00:00, 50.91it/s]
# 100% 788/788 [00:15<00:00, 51.47it/s]
# 100% 847/847 [00:16<00:00, 51.15it/s]
#
# ################################################################################
# Computing OOD metrics with MSP normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6900398406374502, Clf Bal Acc: 0.6875482181574245
# SRC->TAR1:      AUROC: 0.6433, FPR95: 0.9264, AUPR_IN: 0.7813, AUPR_OUT: 0.4660
# SRC->TAR2:      AUROC: 0.6990, FPR95: 0.8985, AUPR_IN: 0.8052, AUPR_OUT: 0.5508
# SRC->TAR1+TAR2: AUROC: 0.6722, FPR95: 0.9119, AUPR_IN: 0.6787, AUPR_OUT: 0.6749
# to spreadsheet: 0.6433307379618581,0.9263959390862944,0.7812713717011314,0.46600615812278123,0.6990065711181248,0.898465171192444,0.8052016807925662,0.550769253380015,0.6721732032116183,0.9119266055045872,0.6786920300212591,0.6749385907032135
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with MLS normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6900398406374502, Clf Bal Acc: 0.6875482181574245
# SRC->TAR1:      AUROC: 0.6610, FPR95: 0.9454, AUPR_IN: 0.7968, AUPR_OUT: 0.4676
# SRC->TAR2:      AUROC: 0.6944, FPR95: 0.8855, AUPR_IN: 0.8074, AUPR_OUT: 0.5453
# SRC->TAR1+TAR2: AUROC: 0.6783, FPR95: 0.9144, AUPR_IN: 0.6930, AUPR_OUT: 0.6733
# to spreadsheet: 0.6610107792181528,0.9454314720812182,0.7968013311512236,0.4675561003302816,0.6944246626245902,0.885478158205431,0.8073714773974628,0.5453381724595724,0.678320601386503,0.9143730886850153,0.6930108442285805,0.6732601516437906
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with entropy normality score...
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6900398406374502, Clf Bal Acc: 0.6875482181574245
# SRC->TAR1:      AUROC: 0.6417, FPR95: 0.9239, AUPR_IN: 0.7810, AUPR_OUT: 0.4618
# SRC->TAR2:      AUROC: 0.6998, FPR95: 0.8725, AUPR_IN: 0.8057, AUPR_OUT: 0.5539
# SRC->TAR1+TAR2: AUROC: 0.6718, FPR95: 0.8972, AUPR_IN: 0.6790, AUPR_OUT: 0.6748
# to spreadsheet: 0.6417446963415374,0.9238578680203046,0.7809833556305283,0.46178549505019584,0.6998480693518723,0.872491145218418,0.8057319326877106,0.5538964735351948,0.6718447311670749,0.8972477064220183,0.6790097730755531,0.6747779097320405
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with distance from train features...
#   0% 0/2378 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 2378/2378 [00:15<00:00, 154.29it/s]
# 100% 1255/1255 [00:24<00:00, 50.44it/s]
# 100% 788/788 [00:15<00:00, 49.72it/s]
# 100% 847/847 [00:17<00:00, 49.41it/s]
# Euclidean distances in a non-normalized space:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6764940239043825, Clf Bal Acc: 0.6693323538702021
# SRC->TAR1:      AUROC: 0.5627, FPR95: 0.9619, AUPR_IN: 0.6938, AUPR_OUT: 0.4098
# SRC->TAR2:      AUROC: 0.7523, FPR95: 0.7403, AUPR_IN: 0.7990, AUPR_OUT: 0.6493
# SRC->TAR1+TAR2: AUROC: 0.6609, FPR95: 0.8471, AUPR_IN: 0.5964, AUPR_OUT: 0.6959
# to spreadsheet: 0.5626852994114911,0.9619289340101523,0.6938154043600476,0.409750197962303,0.7522749615469645,0.7402597402597403,0.7990236926220252,0.6493254980149411,0.6609008613862593,0.8470948012232415,0.5963964515160303,0.6959265320399926
#
# Euclidean distances with prototypes:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.21274900398406374, Clf Bal Acc: 0.2
# SRC->TAR1:      AUROC: 0.5157, FPR95: 0.9581, AUPR_IN: 0.6354, AUPR_OUT: 0.3852
# SRC->TAR2:      AUROC: 0.6590, FPR95: 0.8453, AUPR_IN: 0.7002, AUPR_OUT: 0.5633
# SRC->TAR1+TAR2: AUROC: 0.5900, FPR95: 0.8997, AUPR_IN: 0.4992, AUPR_OUT: 0.6443
# to spreadsheet: 0.51574413007867,0.9581218274111675,0.6354168270824997,0.3852418500736178,0.6590191771285578,0.8453364817001181,0.7001798054869419,0.5633226371452877,0.5899667385503856,0.8996941896024465,0.4991502661830362,0.6443108465432402
#
# Cosine similarities on the hypersphere:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.6637450199203188, Clf Bal Acc: 0.6544711148695878
# SRC->TAR1:      AUROC: 0.5890, FPR95: 0.9581, AUPR_IN: 0.7298, AUPR_OUT: 0.4190
# SRC->TAR2:      AUROC: 0.7032, FPR95: 0.8973, AUPR_IN: 0.7808, AUPR_OUT: 0.5641
# SRC->TAR1+TAR2: AUROC: 0.6482, FPR95: 0.9266, AUPR_IN: 0.6165, AUPR_OUT: 0.6607
# to spreadsheet: 0.5890412967419661,0.9581218274111675,0.7298328074440832,0.41904556041606866,0.703156676716981,0.89728453364817,0.7807839431107652,0.5640781244154017,0.6481579492427842,0.926605504587156,0.6164939742974871,0.6607206341572112
#
# Cosine similarities with prototypes:
# AUROC - Src label: 1, Tar label: 0
# Src Test - Clf Acc: 0.21274900398406374, Clf Bal Acc: 0.2
# SRC->TAR1:      AUROC: 0.5119, FPR95: 0.9454, AUPR_IN: 0.6531, AUPR_OUT: 0.3928
# SRC->TAR2:      AUROC: 0.5941, FPR95: 0.9681, AUPR_IN: 0.6973, AUPR_OUT: 0.4473
# SRC->TAR1+TAR2: AUROC: 0.5545, FPR95: 0.9572, AUPR_IN: 0.5136, AUPR_OUT: 0.5915
# to spreadsheet: 0.5118702853560377,0.9454314720812182,0.6531105461092916,0.39279185080749623,0.5940789380847331,0.9681227863046045,0.6972852006529073,0.4473439797399672,0.5544578871060102,0.9571865443425076,0.5135949463724194,0.5914792658617071
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with ODIN normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [01:09<00:00, 18.01it/s]
# 100% 788/788 [00:43<00:00, 18.18it/s]
# 100% 847/847 [00:46<00:00, 18.24it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6601, FPR95: 0.9454, AUPR_IN: 0.7964, AUPR_OUT: 0.4670
# SRC->TAR2:      AUROC: 0.6943, FPR95: 0.8855, AUPR_IN: 0.8074, AUPR_OUT: 0.5450
# SRC->TAR1+TAR2: AUROC: 0.6778, FPR95: 0.9144, AUPR_IN: 0.6928, AUPR_OUT: 0.6729
# to spreadsheet: 0.6601264990798228,0.9454314720812182,0.796361900177698,0.4670340002576501,0.6942962506526432,0.885478158205431,0.807363904126167,0.5450478229947151,0.6778278933196876,0.9143730886850153,0.6927714930100657,0.6729014803309579
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with Energy normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [00:27<00:00, 45.41it/s]
# 100% 788/788 [00:17<00:00, 45.43it/s]
# 100% 847/847 [00:18<00:00, 45.15it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6621, FPR95: 0.9416, AUPR_IN: 0.7975, AUPR_OUT: 0.4678
# SRC->TAR2:      AUROC: 0.6929, FPR95: 0.8843, AUPR_IN: 0.8064, AUPR_OUT: 0.5432
# SRC->TAR1+TAR2: AUROC: 0.6780, FPR95: 0.9119, AUPR_IN: 0.6928, AUPR_OUT: 0.6724
# to spreadsheet: 0.6620785891965134,0.9416243654822335,0.7974753599914728,0.4677881027676366,0.6928903041905576,0.8842975206611571,0.8064481137952826,0.5432033953653572,0.6780403767194221,0.9119266055045872,0.6928270191169077,0.6723554614565617
# ################################################################################
#
# ################################################################################
# Computing OOD metrics with GradNorm normality score...
#   0% 0/1255 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 1255/1255 [00:42<00:00, 29.49it/s]
# 100% 788/788 [00:26<00:00, 29.40it/s]
# 100% 847/847 [00:28<00:00, 29.46it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6813, FPR95: 0.9505, AUPR_IN: 0.8082, AUPR_OUT: 0.4791
# SRC->TAR2:      AUROC: 0.6613, FPR95: 0.9315, AUPR_IN: 0.7836, AUPR_OUT: 0.4942
# SRC->TAR1+TAR2: AUROC: 0.6709, FPR95: 0.9407, AUPR_IN: 0.6820, AUPR_OUT: 0.6541
# to spreadsheet: 0.6813102918276134,0.950507614213198,0.8082348289139993,0.47912560771583934,0.6612520402451587,0.9315230224321134,0.7836479313926856,0.49424863113755513,0.6709192587448372,0.9406727828746178,0.6820149908420525,0.6540631640165605
# ################################################################################
#
# ################################################################################
# Building React validation loader...
# ModelNet40_OOD - Reading data from h5py file: ./3D_OS_release_data/modelnet40_normal_resampled/ood_sets_cache/SR1_test.h5
# ModelNet40_OOD - split: test, categories: {'chair': 0, 'bookshelf': 1, 'door': 2, 'sink': 3, 'sofa': 4}
# React Val - SR1 data len: 340
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% 340/340 [00:02<00:00, 114.59it/s]
# t = 3.6323
# Computing OOD metrics with React (+Energy) normality score, ID-dependent threshold (=3.6323)...
# React - using SR1 test to compute threshold
# 100% 1255/1255 [00:27<00:00, 45.41it/s]
# 100% 788/788 [00:17<00:00, 45.42it/s]
# 100% 847/847 [00:18<00:00, 45.18it/s]
# AUROC - Src label: 1, Tar label: 0
# SRC->TAR1:      AUROC: 0.6509, FPR95: 0.9378, AUPR_IN: 0.7748, AUPR_OUT: 0.4661
# SRC->TAR2:      AUROC: 0.7026, FPR95: 0.8855, AUPR_IN: 0.8039, AUPR_OUT: 0.5566
# SRC->TAR1+TAR2: AUROC: 0.6777, FPR95: 0.9107, AUPR_IN: 0.6692, AUPR_OUT: 0.6777
# to spreadsheet: 0.6508605173215767,0.9378172588832487,0.7748054281845824,0.4661046366439437,0.70259316923569,0.885478158205431,0.8039393113580332,0.5566203942000447,0.6776602458666862,0.9107033639143731,0.6691522022303651,0.6777180066356637
# ################################################################################
